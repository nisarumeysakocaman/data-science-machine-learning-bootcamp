# %% [markdown]
# #Veri Bilimi Eğitimi

# %% [markdown]
# ## Veri Setini Tanıma
# Amaç:
# 1. Veri setinin genel yapısını tanımak ve temel özelliklerini incelemek
# 2. Veri analizi öncesi gerekli ilk kontrolleri uygulamak
# I
# Adımlar:
# 1. Veri setini yükle
# 2. Veri setinin ilk ve son satırlarını incele
# 3. Veri setinin boyutunu ve sütunlarını kontrol etmek
# 4. Veri setinin genel bilgisini incele
# 5. Özet istatistikleri görüntüle
# 6. Veri teiplerini kontrol et
# 7. Sayısal ve kategorik sütunları ayırmak
# 8. Benzersiz (unique) değer sayılarını incelemek

# %%
import pandas as pd

# %%
# 1. veri setini yükleme
df = pd.read_csv("e_ticaret_veri_seti.csv")

# %%
#ilk 5 satırı gösterme
df.head()
# Out:
#   siparis_id musteri_id       siparis_tarihi      sehir              bolge  \
# 0  SIP101125    MUS1391  2024-01-13 17:06:00   İstanbul            Marmara
# 1  SIP100837    MUS1347  2025-03-17 21:13:00  Gaziantep  Güneydoğu Anadolu
# 2  SIP100050    MUS1066  2025-06-03 12:42:00    Kayseri         İç Anadolu
# 3  SIP100263    MUS1008  2024-08-10 15:13:00    Antalya            Akdeniz
# 4  SIP100707    MUS1291  2024-08-19 08:24:00  Gaziantep  Güneydoğu Anadolu
#
#      kategori              urun_adi  adet  birim_fiyat  indirim_orani  \
# 0    Kozmetik          Nemlendirici     1       414.51           0.05
# 1        Spor           Dambıl Seti     2      1475.15           0.10
# 2       Kitap  İş Analitiği Rehberi     1       289.02           0.05
# 3       Kitap          Girişimcilik     5       194.78           0.00
# 4  Elektronik             Powerbank     3       841.80           0.05
#
#    kargo_ucreti      odeme_turu musteri_tipi  teslimat_gunu  musteri_puani  \
# 0          49.9     Kredi Kartı         Yeni            3.0            5.0
# 1          29.9     Banka Kartı          VIP            4.0            1.0
# 2          29.9     Kredi Kartı       Mevcut            6.0            2.0
# 3          49.9    Kapıda Ödeme         Yeni            3.0            5.0
# 4          39.9  Dijital Cüzdan       Mevcut            4.0            5.0
#
#   iade_durumu  kar_marji_orani  toplam_tutar
# 0       Hayır            0.220        443.68
# 1       Hayır            0.361       2685.17
# 2       Hayır            0.348        304.47
# 3       Hayır            0.250       1023.80
# 4       Hayır            0.280       2439.03

# %%
#son 5 satırı gösterme
df.tail()
# Out:
#      siparis_id musteri_id       siparis_tarihi      sehir              bolge  \
# 1423  SIP101093    MUS1187  2024-06-08 20:42:00   İstanbul            Marmara
# 1424  SIP101193    MUS1297  2025-11-06 08:17:00  Gaziantep  Güneydoğu Anadolu
# 1425  SIP101210    MUS1122  2025-03-07 09:07:00        NaN            Marmara
# 1426  SIP101060    MUS1189  2025-04-19 21:52:00    Kocaeli            Marmara
# 1427  SIP100642    MUS1289  2024-09-22 16:36:00     Ankara         İç Anadolu
#
#         kategori         urun_adi  adet  birim_fiyat  indirim_orani  \
# 1423        Spor        Yoga Matı     1       772.23           0.00
# 1424        Spor            Suluk     2       187.03           0.00
# 1425  Elektronik           Webcam     4       894.47           0.10
# 1426       Kitap  Veri Bilimi 101     2       248.55           0.05
# 1427    Kozmetik      Güneş Kremi     1       424.84           0.20
#
#       kargo_ucreti      odeme_turu musteri_tipi  teslimat_gunu  musteri_puani  \
# 1423          29.9     Kredi Kartı       Mevcut            3.0            2.0
# 1424          59.9     Kredi Kartı         Yeni            2.0            4.0
# 1425          49.9     Kredi Kartı       Mevcut            3.0            5.0
# 1426          59.9     banka karti         Yeni            4.0            3.0
# 1427           0.0  Dijital Cüzdan         Yeni            2.0            4.0
#
#      iade_durumu  kar_marji_orani  toplam_tutar
# 1423       Hayır            0.275        802.13
# 1424        Evet            0.243        433.96
# 1425       Hayır            0.355       3269.99
# 1426       Hayır            0.373        532.14
# 1427       Hayır            0.317        339.87

# %%
#veri setinin boyutunu bulma
satir_sayisi=df.shape[0]
satir_sayisi
# Out:
# 1428

# %%
#veri setinin sütun sayısını öğrenme
sutun_sayisi=df.shape[1]
sutun_sayisi
# Out:
# 18

# %%
#sütun isimleri
for i,sutun in enumerate(df.columns,start=1):
  print(f"{i}. {sutun}")
# Out:
# 1. siparis_id
# 2. musteri_id
# 3. siparis_tarihi
# 4. sehir
# 5. bolge
# 6. kategori
# 7. urun_adi
# 8. adet
# 9. birim_fiyat
# 10. indirim_orani
# 11. kargo_ucreti
# 12. odeme_turu
# 13. musteri_tipi
# 14. teslimat_gunu
# 15. musteri_puani
# 16. iade_durumu
# 17. kar_marji_orani
# 18. toplam_tutar

# %%
#veri setinin genel bilgisini inceleme
df.info() #sütun isimleri,veri tipleri,missing value
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1428 entries, 0 to 1427
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   siparis_id       1428 non-null   object
#  1   musteri_id       1428 non-null   object
#  2   siparis_tarihi   1428 non-null   object
#  3   sehir            1403 non-null   object
#  4   bolge            1428 non-null   object
#  5   kategori         1428 non-null   object
#  6   urun_adi         1428 non-null   object
#  7   adet             1428 non-null   int64
#  8   birim_fiyat      1428 non-null   float64
#  9   indirim_orani    1412 non-null   float64
#  10  kargo_ucreti     1428 non-null   float64
#  11  odeme_turu       1393 non-null   object
#  12  musteri_tipi     1386 non-null   object
#  13  teslimat_gunu    1400 non-null   float64
#  14  musteri_puani    1372 non-null   float64
#  15  iade_durumu      1428 non-null   object
#  16  kar_marji_orani  1428 non-null   float64
#  17  toplam_tutar     1428 non-null   float64
# dtypes: float64(7), int64(1), object(10)
# memory usage: 200.9+ KB

# %%
#özel istatistikleri görüntüleme
df.describe()  #sayısal sütunlar için temel istatistikleri gösterir
# Out:
#               adet   birim_fiyat  indirim_orani  kargo_ucreti  teslimat_gunu  \
# count  1428.000000   1428.000000    1412.000000   1428.000000    1400.000000
# mean      2.136555    658.477654       0.052054     39.725140       3.370714
# std       2.015770   1042.414639       0.060115     14.185017       1.825990
# min       1.000000     93.110000       0.000000      0.000000       1.000000
# 25%       1.000000    199.185000       0.000000     29.900000       2.000000
# 50%       2.000000    287.120000       0.050000     39.900000       3.000000
# 75%       3.000000    819.177500       0.100000     49.900000       4.000000
# max      38.000000  18145.230000       0.200000     59.900000      31.000000
#
#        musteri_puani  kar_marji_orani  toplam_tutar
# count    1372.000000      1428.000000   1428.000000
# mean        4.002187         0.302799   1370.590336
# std         1.096707         0.069795   2961.689500
# min         0.000000         0.180000     89.680000
# 25%         3.000000         0.244750    323.855000
# 50%         4.000000         0.305000    669.135000
# 75%         5.000000         0.362000   1390.950000
# max         7.000000         0.420000  63870.200000

# %%
#veri tiplerini kontrol etme
df.dtypes
# Out:
# siparis_id          object
# musteri_id          object
# siparis_tarihi      object
# sehir               object
# bolge               object
# kategori            object
# urun_adi            object
# adet                 int64
# birim_fiyat        float64
# indirim_orani      float64
# kargo_ucreti       float64
# odeme_turu          object
# musteri_tipi        object
# teslimat_gunu      float64
# musteri_puani      float64
# iade_durumu         object
# kar_marji_orani    float64
# toplam_tutar       float64
# dtype: object

# %%
#sayısal ve kategorik sütunların ayrılması
#sayısal: float64 ,int64
#kategorik: object
sayisal_sutunlar=df.select_dtypes(include=["float64","int64"]).columns
sayisal_sutunlar
# Out:
# Index(['adet', 'birim_fiyat', 'indirim_orani', 'kargo_ucreti', 'teslimat_gunu',
#        'musteri_puani', 'kar_marji_orani', 'toplam_tutar'],
#       dtype='object')

# %%
#kategorik: object
kategorik_sutunlar=df.select_dtypes(include=["object"]).columns
kategorik_sutunlar
# Out:
# Index(['siparis_id', 'musteri_id', 'siparis_tarihi', 'sehir', 'bolge',
#        'kategori', 'urun_adi', 'odeme_turu', 'musteri_tipi', 'iade_durumu'],
#       dtype='object')

# %%
#Benzersiz (unique) değer sayılarını incelemek
for sutun in df.columns:
  print(f"{sutun}: {df[sutun].nunique()}")
# Out:
# siparis_id: 1400
# musteri_id: 422
# siparis_tarihi: 1398
# sehir: 19
# bolge: 6
# kategori: 15
# urun_adi: 30
# adet: 10
# birim_fiyat: 1381
# indirim_orani: 5
# kargo_ucreti: 5
# odeme_turu: 12
# musteri_tipi: 7
# teslimat_gunu: 11
# musteri_puani: 8
# iade_durumu: 2
# kar_marji_orani: 241
# toplam_tutar: 1397

# %% [markdown]
# ## Kayıp Veri (Missing Value)
# Amaç:
# 1. Eksik veri tespiti ve farklı eksik veri çözüm yöntemlerini uygulamak
# 2. Eğitimde kullanılacak güncel veri setini kaydetme
# Adımlar:
# 1. Veri setini yükleme
# I
# 2. Eksik verileri tespit etme
# 3. Eksik veri oranlarını hesaplama
# 4. Eksik veri içeren satırları incele
# 5. Eksik verileri silmek
# 6. Sayısal eksik verileri ortalama ile doldur
# 7. Sayısal eksik verileri medyan ile doldur
# 8. Sayısal eksik verileri mod ile doldur
# 9. Kategorik eksik verileri mod ile doldur
# 10. Kategorik eksik verileri sabit bir değer ile doldurmak
# 11. Eğitimde kullanılacak olan güncel veri setini oluştur
# 12. Düzenlenmiş veri setini kaydet

# %%
import pandas as pd

# %%
#veri setini yükleme
df=pd.read_csv("e_ticaret_veri_seti.csv")

# %%
#eksik verileri tespit etme
df.isnull().sum()
# Out:
# siparis_id          0
# musteri_id          0
# siparis_tarihi      0
# sehir              25
# bolge               0
# kategori            0
# urun_adi            0
# adet                0
# birim_fiyat         0
# indirim_orani      16
# kargo_ucreti        0
# odeme_turu         35
# musteri_tipi       42
# teslimat_gunu      28
# musteri_puani      56
# iade_durumu         0
# kar_marji_orani     0
# toplam_tutar        0
# dtype: int64

# %%
#eksik veri oranlarını hesapla
eksik_sayilari=  df.isnull().sum()
eksik_oranlari=(eksik_sayilari/len(df))*100
eksik_oranlari
# Out:
# siparis_id         0.000000
# musteri_id         0.000000
# siparis_tarihi     0.000000
# sehir              1.750700
# bolge              0.000000
# kategori           0.000000
# urun_adi           0.000000
# adet               0.000000
# birim_fiyat        0.000000
# indirim_orani      1.120448
# kargo_ucreti       0.000000
# odeme_turu         2.450980
# musteri_tipi       2.941176
# teslimat_gunu      1.960784
# musteri_puani      3.921569
# iade_durumu        0.000000
# kar_marji_orani    0.000000
# toplam_tutar       0.000000
# dtype: float64

# %%
#eksik veri içeren satırları inceleme
eksik_veri_olan_satirlar=df[df.isnull().any(axis=1)]
eksik_veri_olan_satirlar.head(10)
# Out:
#    siparis_id musteri_id       siparis_tarihi     sehir       bolge  \
# 19  SIP100677    MUS1148  2024-07-11 16:24:00     Adana     Akdeniz
# 33  SIP101126    MUS1406  2024-09-11 20:05:00    Mersin     Akdeniz
# 50  SIP101040    MUS1386  2025-04-01 09:30:00   Trabzon   Karadeniz
# 60  SIP100890    MUS1271  2024-11-07 19:47:00     İzmir         Ege
# 61  SIP101317    MUS1060  2024-09-05 20:49:00       NaN     Akdeniz
# 70  SIP100715    MUS1033  2024-11-10 21:50:00  İstanbul     Marmara
# 82  SIP100807    MUS1431  2025-01-07 14:12:00    Ankara  İç Anadolu
# 84  SIP100679    MUS1310  2024-05-20 18:51:00     İzmir         Ege
# 86  SIP101071    MUS1131  2024-09-18 12:24:00       NaN  İç Anadolu
# 92  SIP101366    MUS1347  2025-03-04 14:00:00     Bursa     Marmara
#
#        kategori            urun_adi  adet  birim_fiyat  indirim_orani  \
# 19         Spor         Dambıl Seti     4      1517.65            0.0
# 33   Elektronik  Bluetooth Hoparlör     1      1159.89            0.1
# 50         Spor         Dambıl Seti     1      1554.15            0.0
# 60        Kitap        Girişimcilik     4       216.38            NaN
# 61  Ev ve Yaşam      Saklama Kutusu     1       233.63            0.1
# 70  Ev ve Yaşam              Termos     1       552.05            0.0
# 82     Kozmetik         Güneş Kremi     1       451.28            0.0
# 84  Ev ve Yaşam              Termos     2       477.62            0.0
# 86   Elektronik           Powerbank     1       816.74            0.0
# 92  Ev ve Yaşam           Organizer     1       272.40            0.0
#
#     kargo_ucreti      odeme_turu musteri_tipi  teslimat_gunu  musteri_puani  \
# 19          29.9    Kapıda Ödeme       Mevcut            3.0            NaN
# 33          39.9     Kredi Kartı          NaN            2.0            4.0
# 50          49.9     Banka Kartı          NaN            4.0            5.0
# 60          49.9     Kredi Kartı         Yeni            1.0            3.0
# 61          29.9  Dijital Cüzdan         Yeni            5.0            2.0
# 70          39.9             NaN       Mevcut            2.0            3.0
# 82          49.9     Kredi Kartı          NaN            4.0            5.0
# 84          49.9     Kredi Kartı       Mevcut            NaN            4.0
# 86          39.9     Banka Kartı         Yeni            3.0            5.0
# 92          29.9     Kredi Kartı       Mevcut            1.0            NaN
#
#    iade_durumu  kar_marji_orani  toplam_tutar
# 19       Hayır            0.311       6100.50
# 33       Hayır            0.204       1083.80
# 50       Hayır            0.217       1604.05
# 60       Hayır            0.199        915.42
# 61       Hayır            0.385        240.17
# 70       Hayır            0.185        591.95
# 82       Hayır            0.315        501.18
# 84       Hayır            0.323       1005.14
# 86       Hayır            0.301        856.64
# 92       Hayır            0.212        302.30

# %%
#eksik verileri silme
df_silinen=df.dropna()

# %%
df_silinen.shape
# Out:
# (1239, 18)

# %%
#sayısal eksik verilerin ortalama ile doldurulması
df_ortalama=df.copy()
sayisal_sutunlar=df_ortalama.select_dtypes(include=["float64","int64"]).columns
sayisal_sutunlar
# Out:
# Index(['adet', 'birim_fiyat', 'indirim_orani', 'kargo_ucreti', 'teslimat_gunu',
#        'musteri_puani', 'kar_marji_orani', 'toplam_tutar'],
#       dtype='object')

# %%
for sutun in sayisal_sutunlar:
  df_ortalama[sutun]=df_ortalama[sutun].fillna(df_ortalama[sutun].mean())

# %%
df_ortalama[sayisal_sutunlar].isnull().sum()
# Out:
# adet               0
# birim_fiyat        0
# indirim_orani      0
# kargo_ucreti       0
# teslimat_gunu      0
# musteri_puani      0
# kar_marji_orani    0
# toplam_tutar       0
# dtype: int64

# %%
#sayısal eksik verileri medyan ile doldurma
df_medyan=df.copy()
for sutun in sayisal_sutunlar:
  df_medyan[sutun]=df_medyan[sutun].fillna(df_medyan[sutun].median())
df_medyan[sayisal_sutunlar].isnull().sum()
# Out:
# adet               0
# birim_fiyat        0
# indirim_orani      0
# kargo_ucreti       0
# teslimat_gunu      0
# musteri_puani      0
# kar_marji_orani    0
# toplam_tutar       0
# dtype: int64

# %%
#sayısal eksik verileri mod ile doldurma
df_mod=df.copy()
for sutun in sayisal_sutunlar:
  mod_degeri=df_mod[sutun].mode()[0]
  df_mod[sutun]=df_mod[sutun].fillna(mod_degeri)
df_mod[sayisal_sutunlar].isnull().sum()
# Out:
# adet               0
# birim_fiyat        0
# indirim_orani      0
# kargo_ucreti       0
# teslimat_gunu      0
# musteri_puani      0
# kar_marji_orani    0
# toplam_tutar       0
# dtype: int64

# %%
#kategorik eksik verileri mod ile doldurma
df_mod_kategorik=df.copy()
kategorik_sutunlar=df_mod_kategorik.select_dtypes(include=["object"]).columns
kategorik_sutunlar
# Out:
# Index(['siparis_id', 'musteri_id', 'siparis_tarihi', 'sehir', 'bolge',
#        'kategori', 'urun_adi', 'odeme_turu', 'musteri_tipi', 'iade_durumu'],
#       dtype='object')

# %%
for sutun in kategorik_sutunlar:
  mod_degeri=df_mod_kategorik[sutun].mode()[0]
  df_mod_kategorik[sutun]=df_mod_kategorik[sutun].fillna(mod_degeri)

# %%
df_mod_kategorik[kategorik_sutunlar].isnull().sum()
# Out:
# siparis_id        0
# musteri_id        0
# siparis_tarihi    0
# sehir             0
# bolge             0
# kategori          0
# urun_adi          0
# odeme_turu        0
# musteri_tipi      0
# iade_durumu       0
# dtype: int64

# %%
#kategorik eksik verileri sabit bir değer ile doldurma
df_sabit=df.copy()
for sutun in kategorik_sutunlar:
  df_sabit[sutun]=df_sabit[sutun].fillna("Belirtilmemiş")

# %%
df_sabit[kategorik_sutunlar].isnull().sum()
# Out:
# siparis_id        0
# musteri_id        0
# siparis_tarihi    0
# sehir             0
# bolge             0
# kategori          0
# urun_adi          0
# odeme_turu        0
# musteri_tipi      0
# iade_durumu       0
# dtype: int64

# %%
#eğitimde kullanacağımız güncel veri seti
#sayısal eksik verileri medyan ile doldur
#kategorik eksik verileri mod ile doldur

# %%
df_guncel=df.copy()

# %%
for sutun in sayisal_sutunlar:
  df_guncel[sutun]=df_guncel[sutun].fillna(df_guncel[sutun].median())

# %%
for sutun in kategorik_sutunlar:
  mod_degeri=df_guncel[sutun].mode()[0]
  df_guncel[sutun]=df_guncel[sutun].fillna(mod_degeri)

# %%
df_guncel.isnull().sum()
# Out:
# siparis_id         0
# musteri_id         0
# siparis_tarihi     0
# sehir              0
# bolge              0
# kategori           0
# urun_adi           0
# adet               0
# birim_fiyat        0
# indirim_orani      0
# kargo_ucreti       0
# odeme_turu         0
# musteri_tipi       0
# teslimat_gunu      0
# musteri_puani      0
# iade_durumu        0
# kar_marji_orani    0
# toplam_tutar       0
# dtype: int64

# %%
#düzenlenmiş veri setini kaydet
kayit_dosyasi="e_ticaret_veri_seti_eksik_veriler_guncellendi.csv"
df_guncel.to_csv(kayit_dosyasi , index=False)

# %% [markdown]
# ## Veri Tipleri ve Dönüşümler
# Amaç:
# 1. Veri setindeki sütunların veri tiplerini incelemek ve gerekli dönüşümleri uygulamak
# 1. Eğitimde kullanılacak güncel veri setini oluşturarak kaydetmek
#
# Adımlar:
# 1. Veri setini yüklemek
# 2. Veri tiplerini incelemek
# 3. Sayısal, kategorik ve tarih sütunlarını belirlemek
# 4. Sipariş tarihi sütununu datetime tipine dönüştürmek (string -> datetime)
# 5. Tarih sütunundan yeni özellikler üretmek (Feature extraction)
# 6. Kategorik sütunları category tipine dönüştürmek (string -> category)
# 7. Dönüşüm sonrası veri tipi kontrol etmek
# 8. Güncellenmiş veri setini kaydetmek

# %%
import pandas as pd

# %%
#veri setini yüklemek
df=pd.read_csv("e_ticaret_veri_seti_eksik_veriler_guncellendi.csv")

# %%
#veri tiplerini incelemek
df.dtypes
# Out:
# siparis_id          object
# musteri_id          object
# siparis_tarihi      object
# sehir               object
# bolge               object
# kategori            object
# urun_adi            object
# adet                 int64
# birim_fiyat        float64
# indirim_orani      float64
# kargo_ucreti       float64
# odeme_turu          object
# musteri_tipi        object
# teslimat_gunu      float64
# musteri_puani      float64
# iade_durumu         object
# kar_marji_orani    float64
# toplam_tutar       float64
# dtype: object

# %%
#sayısal,kategorik ve tarih sütunlarını belirlemek
sayisal_sutunlar=df.select_dtypes(include=["float64","int64"]).columns.tolist()
sayisal_sutunlar
# Out:
# ['adet',
#  'birim_fiyat',
#  'indirim_orani',
#  'kargo_ucreti',
#  'teslimat_gunu',
#  'musteri_puani',
#  'kar_marji_orani',
#  'toplam_tutar']

# %%
kategorik_sutunlar=df.select_dtypes(include=["object"]).columns.tolist()
kategorik_sutunlar
# Out:
# ['siparis_id',
#  'musteri_id',
#  'siparis_tarihi',
#  'sehir',
#  'bolge',
#  'kategori',
#  'urun_adi',
#  'odeme_turu',
#  'musteri_tipi',
#  'iade_durumu']

# %%
 #sipariş tarih sütununu datetime tipine dönüştürmek (string -> datetime)
df["siparis_tarihi"]=pd.to_datetime(df["siparis_tarihi"])
df["siparis_tarihi"].dtype
# Out:
# dtype('<M8[ns]')

# %%
df.dtypes
# Out:
# siparis_id                 object
# musteri_id                 object
# siparis_tarihi     datetime64[ns]
# sehir                      object
# bolge                      object
# kategori                   object
# urun_adi                   object
# adet                        int64
# birim_fiyat               float64
# indirim_orani             float64
# kargo_ucreti              float64
# odeme_turu                 object
# musteri_tipi               object
# teslimat_gunu             float64
# musteri_puani             float64
# iade_durumu                object
# kar_marji_orani           float64
# toplam_tutar              float64
# dtype: object

# %%
#Tarih sütunundan yeni özelliklerin üretilmesi
#zaman bazlı analizlerde yıl,ay, gün ve hafta günü bilgilerini üretiyoruz.
df["siparis_yili"]=df["siparis_tarihi"].dt.year
df["siparis_ayi"]=df["siparis_tarihi"].dt.month
df["siparis_gunu"]=df["siparis_tarihi"].dt.day
df["haftanin_gunu"]=df["siparis_tarihi"].dt.day_name()
df.head()
# Out:
#   siparis_id musteri_id      siparis_tarihi      sehir              bolge  \
# 0  SIP101125    MUS1391 2024-01-13 17:06:00   İstanbul            Marmara
# 1  SIP100837    MUS1347 2025-03-17 21:13:00  Gaziantep  Güneydoğu Anadolu
# 2  SIP100050    MUS1066 2025-06-03 12:42:00    Kayseri         İç Anadolu
# 3  SIP100263    MUS1008 2024-08-10 15:13:00    Antalya            Akdeniz
# 4  SIP100707    MUS1291 2024-08-19 08:24:00  Gaziantep  Güneydoğu Anadolu
#
#      kategori              urun_adi  adet  birim_fiyat  indirim_orani  \
# 0    Kozmetik          Nemlendirici     1       414.51           0.05
# 1        Spor           Dambıl Seti     2      1475.15           0.10
# 2       Kitap  İş Analitiği Rehberi     1       289.02           0.05
# 3       Kitap          Girişimcilik     5       194.78           0.00
# 4  Elektronik             Powerbank     3       841.80           0.05
#
#    kargo_ucreti      odeme_turu musteri_tipi  teslimat_gunu  musteri_puani  \
# 0          49.9     Kredi Kartı         Yeni            3.0            5.0
# 1          29.9     Banka Kartı          VIP            4.0            1.0
# 2          29.9     Kredi Kartı       Mevcut            6.0            2.0
# 3          49.9    Kapıda Ödeme         Yeni            3.0            5.0
# 4          39.9  Dijital Cüzdan       Mevcut            4.0            5.0
#
#   iade_durumu  kar_marji_orani  toplam_tutar  siparis_yili  siparis_ayi  \
# 0       Hayır            0.220        443.68          2024            1
# 1       Hayır            0.361       2685.17          2025            3
# 2       Hayır            0.348        304.47          2025            6
# 3       Hayır            0.250       1023.80          2024            8
# 4       Hayır            0.280       2439.03          2024            8
#
#    siparis_gunu haftanin_gunu
# 0            13      Saturday
# 1            17        Monday
# 2             3       Tuesday
# 3            10      Saturday
# 4            19        Monday

# %%
#kategorik sütunları category tipine dönüştürme
kategorik_donusum_sutunlari=[
    "sehir",
    "kategori",
    "urun_adi",
    "odeme_turu",
    "musteri_tipi",
    "haftanin_gunu"

]

# %%
for sutun in kategorik_donusum_sutunlari:
  df[sutun]=df[sutun].astype("category")

# %%
df.dtypes
# Out:
# siparis_id                 object
# musteri_id                 object
# siparis_tarihi     datetime64[ns]
# sehir                    category
# bolge                      object
# kategori                 category
# urun_adi                 category
# adet                        int64
# birim_fiyat               float64
# indirim_orani             float64
# kargo_ucreti              float64
# odeme_turu               category
# musteri_tipi             category
# teslimat_gunu             float64
# musteri_puani             float64
# iade_durumu                object
# kar_marji_orani           float64
# toplam_tutar              float64
# siparis_yili                int32
# siparis_ayi                 int32
# siparis_gunu                int32
# haftanin_gunu            category
# dtype: object

# %%
#güncellenmiş veri setini kaydedelim
df.to_csv("e_ticaret_veri_seti_veri_tipleri_duzenlendi.csv")

# %% [markdown]
# ## Tekrarlayan ve Tutarsız Kayıtlar
# Amaç:
# 1. Veri setindeki tekrarlayan ve tutarsız kayıtları tespit edip temizlemek
# 2. Eğitimde kullanılacak güncel veri setini kaydet
# Adımlar:
# 1. Veri setini yüklemek
# 2. Tekrarlayan kayıtları tespit etmek
# I
# 3. Tekrarlayan kayıtları incelemek
# 4. Tekrarlayan kayıtları temizlemek
# 5. Tutarsız kategorik değerleri incelemek
# 6. Şehir sütunundaki tutarsız değerleri düzeltmek
# 7. Kategori sütunundaki tutarsız değerleri düzeltmek
# 8. Ödeme türü sütunundaki tutarsız değerleri düzeltmek
# 9. Müşteri tipi sütunundaki tutarsız değerleri düzeltmek
# 10. Mantıksal olarak hatalı kayıtları incele
# 11. Mantıksal olarak hatalı kayıtları temizleme
# 12. Güncellenmiş veri setini kaydet

# %%
import pandas as pd

# %%
#veri setini yükleme
df=pd.read_csv("e_ticaret_veri_seti_veri_tipleri_duzenlendi.csv")
df.shape
# Out:
# (1428, 23)

# %%
#tekrarlayan kayıtları tespit et
tekrarlayan_kayitlar=df[df.duplicated()]
len(tekrarlayan_kayitlar)
# Out:
# 0

# %%
#tekrarlayan kayıtları incele
tekrarlayan_kayitlar.head()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, siparis_id, musteri_id, siparis_tarihi, sehir, bolge, kategori, urun_adi, adet, birim_fiyat, indirim_orani, kargo_ucreti, odeme_turu, musteri_tipi, teslimat_gunu, musteri_puani, iade_durumu, kar_marji_orani, toplam_tutar, siparis_yili, siparis_ayi, siparis_gunu, haftanin_gunu]
# Index: []

# %%
#tekrarlayan kayıtları temizle
df=df.drop_duplicates()
df.shape
# Out:
# (1428, 23)

# %%
#tutarsız değerlerin incelenmesi
df["sehir"].unique()
# Out:
# array(['İstanbul', 'Gaziantep', 'Kayseri', 'Antalya', 'Konya', 'Ankara',
#        'Bursa', 'Trabzon', 'Adana', 'Mersin', 'Kocaeli', 'İzmir',
#        'Eskişehir', 'Samsun', 'istanbul', 'ankara', 'Istanbul',
#        'gaziantep', 'Izmir'], dtype=object)

# %%
df["kategori"].unique()
# Out:
# array(['Kozmetik', 'Spor', 'Kitap', 'Elektronik', 'Ofis', 'ofis',
#        'Ev ve Yaşam', 'Elektronik ', 'spor', 'kozmetık', 'ev ve yaşam',
#        'kitap', 'Kozmetik ', 'elektronik', 'Ev&Yaşam'], dtype=object)

# %%
df["odeme_turu"].unique()
# Out:
# array(['Kredi Kartı', 'Banka Kartı', 'Kapıda Ödeme', 'Dijital Cüzdan',
#        'Havale/EFT', 'Kart', 'kredi kartı', 'dijital cüzdan', 'eft',
#        'banka karti', 'Kapida Odeme', 'Havale'], dtype=object)

# %%
df["musteri_tipi"].unique()
# Out:
# array(['Yeni', 'VIP', 'Mevcut', 'yeni', 'Vip', 'mevcut', 'vip'],
#       dtype=object)

# %%
#yardımcı fonksiyon: metinleri normalize edelim
#büyük küçük harf dönüşümü,boşlukların kaldırılması,Türkçe karakter kaynaklı farkların düzenlenmesi
def metin_normalize_et(series):
  return(
      series.astype(str)
      .str.strip()
      .str.lower()
      .str.replace("i̇","i",regex=False)
      .str.replace("ş","s",regex=False)
      .str.replace("ı","i",regex=False)
      .str.replace("ç","c",regex=False)
      .str.replace("ö","o",regex=False)
      .str.replace("ğ","g",regex=False)
      .str.replace("ü","u",regex=False)
      .str.replace("ş","s",regex=False)

  )

# %%
#şehir sütunundaki tutarsız değerleri düzeltme
df["sehir"]=metin_normalize_et(df["sehir"])
df["sehir"].unique()
# Out:
# array(['istanbul', 'gaziantep', 'kayseri', 'antalya', 'konya', 'ankara',
#        'bursa', 'trabzon', 'adana', 'mersin', 'kocaeli', 'izmir',
#        'eskisehir', 'samsun'], dtype=object)

# %%
sehir_duzeltme_haritasi={
    "istanbul": "İstanbul",
    "ankara": "Ankara",
    "izmir": "İzmir",
    "bursa": "Bursa",
    "antalya": "Antalya",
    "kocaeli":"Trabzon",
    "samsun":"Samsun",
    "mersin":"Mersin",
    "gaziantep":"Gaziantep",
    "kayseri": "Kayseri",
    "eskisehir":"Eskisehir",
    "konya":"Konya",
    "adana":"Adana",
    "trabzon": "Trabzon"

}
df["sehir"]=df["sehir"].replace(sehir_duzeltme_haritasi)
df["sehir"].unique()
# Out:
# array(['İstanbul', 'Gaziantep', 'Kayseri', 'Antalya', 'Konya', 'Ankara',
#        'Bursa', 'Trabzon', 'Adana', 'Mersin', 'İzmir', 'Eskisehir',
#        'Samsun'], dtype=object)

# %%
#kategori sütunundaki tutarsız değerleri düzeltme
df["kategori"]=metin_normalize_et(df["kategori"])
df["kategori"].unique()
# Out:
# array(['kozmetik', 'spor', 'kitap', 'elektronik', 'ofis', 'ev ve yasam',
#        'ev&yasam'], dtype=object)

# %%
kategori_duzeltme_haritasi = {
"elektronik": "Elektronik",
"kitap": "Kitap",
"kozmetik": "Kozmetik",
"kozmetik": "Kozmetik",
"spor": "Spor",
"ev yasam": "Ev Yaşam",
"ev ve yasam": "Ev Yaşam",
"ev&yasam": "Ev Yaşam",
"ofis": "ofis"
}
df["kategori"] = df["kategori"].replace(kategori_duzeltme_haritasi)
df["kategori"].unique()
# Out:
# array(['Kozmetik', 'Spor', 'Kitap', 'Elektronik', 'ofis', 'Ev Yaşam'],
#       dtype=object)

# %%
#ödeme türü sütunundaki tutarsız değerleri düzenleme
odeme_turu_duzeltme_haritasi = {
"kredi karti": "Kredi Kartı",
"kart": "Kredi Kartı",
"banka karti": "Banka Kartı",
"dijital cuzdan": "Dijital Cüzdan",
"kapida odeme": "Kapıda Ödeme",
"havale": "Havale/EFT",
"eft": "Havale/EFT",
"havale/eft": "Havale/EFT"
}
df["odeme_turu"]=df["odeme_turu"].replace(odeme_turu_duzeltme_haritasi)
df["odeme_turu"].unique()
# Out:
# array(['Kredi Kartı', 'Banka Kartı', 'Kapıda Ödeme', 'Dijital Cüzdan',
#        'Havale/EFT', 'Kart', 'kredi kartı', 'dijital cüzdan',
#        'Kapida Odeme', 'Havale'], dtype=object)

# %%
#müşreti tipi sütunundaki tutarsız değerleri düzenleme
df["musteri_tipi"]=metin_normalize_et(df["musteri_tipi"])
df["musteri_tipi"].unique()
# Out:
# array(['yeni', 'vip', 'mevcut'], dtype=object)

# %%
musteri_tipi_duzeltme_haritasi = {
"mevcut": "Mevcut",
"yeni":
"Yeni",
"vip": "VIP"
}
df["musteri_tipi"] = df["musteri_tipi"].replace(musteri_tipi_duzeltme_haritasi)
df["musteri_tipi"].unique()
# Out:
# array(['Yeni', 'VIP', 'Mevcut'], dtype=object)

# %%
# 10. mantıksal olarak hatalı kayıtları inceleme
# negatif yada anlamsız değerler bazı kayıtlarda veri kalitesini düşürebilir
hatali_kayitlar = df[
(df["adet"] <= 0) |
(df["toplam_tutar"] <= 0) |
(df["birim_fiyat"] <= 0) |
(df["toplam_tutar"] <= 0) |
(df["teslimat_gunu"] < 0) |
(df["musteri_puani"] < 0) |
(df["musteri_puani"] > 5)
 ]
len(hatali_kayitlar)
# Out:
# 2

# %%
pd.set_option("display.max_columns",None) #tüm sütunları görebilmek için
hatali_kayitlar
# Out:
#       Unnamed: 0 siparis_id musteri_id       siparis_tarihi     sehir  \
# 609          609  SIP100095    MUS1165  2025-10-12 21:31:00  İstanbul
# 1008        1008  SIP101290    MUS1225  2024-01-16 21:46:00   Trabzon
#
#         bolge  kategori            urun_adi  adet  birim_fiyat  indirim_orani  \
# 609   Marmara  Kozmetik             Şampuan     2       190.17           0.10
# 1008  Marmara  Kozmetik  Yüz Temizleme Jeli     2       303.82           0.05
#
#       kargo_ucreti      odeme_turu musteri_tipi  teslimat_gunu  musteri_puani  \
# 609            0.0  Dijital Cüzdan       Mevcut            3.0            6.0
# 1008          29.9     Kredi Kartı         Yeni            5.0            7.0
#
#      iade_durumu  kar_marji_orani  toplam_tutar  siparis_yili  siparis_ayi  \
# 609        Hayır            0.416        342.31          2025           10
# 1008        Evet            0.287        607.16          2024            1
#
#       siparis_gunu haftanin_gunu
# 609             12        Sunday
# 1008            16       Tuesday

# %%
# 11. mantıksal hataları temizleyelim
df = df[
(df["adet"] > 0) &
(df["toplam_tutar"] > 0) &
(df["birim_fiyat"] > 0) &
(df["teslimat_gunu"] >= 0) &
(df["musteri_puani"] >= 0) &
(df["musteri_puani"] <= 5)
]
df.shape
# Out:
# (1426, 23)

# %% [markdown]
# ## Aykırı Değerler (Outliers)
# Amaç:
# 1. Veri setindeki aykırı değerlerin tespit edilmesi ve incelenmesi
# 2. Aykırı değerleri temizleyerek güncel veri setinin oluşturulması
# Adımlar:
# 1. Veri setini yükle
# 2. Sayısal sütunları belirle
# 3. Sayısal sütunların özet istatistiklerini hesapla
# 4. IQR ile aykırı değer sınırlarını hesapla
# 5. Aykırı değer içeren kayıtları tespit etmek
# 6. Aykırı değer sayılarını sütun bazında incelemek
# 7. Aykırı değer içeren kayıtları veri setinden temizlemek
# 8. Temizlenmiş veri setini kaydetmek

# %%
import pandas as pd

# %%
#veri setini yüklemek
df=pd.read_csv("e_ticaret_veri_seti_tekrarlayan_kayitlar_duzenlendi.csv")

# %%
#sayısal sütunların belirlenmesi
sayisal_sutunlar=df.select_dtypes(include=["float64","int64"]).columns.tolist()
sayisal_sutunlar
# Out:
# ['adet',
#  'birim_fiyat',
#  'indirim_orani',
#  'kargo_ucreti',
#  'teslimat_gunu',
#  'musteri_puani',
#  'kar_marji_orani',
#  'toplam_tutar',
#  'siparis_yili',
#  'siparis_ayi',
#  'siparis_gunu']

# %%
#sayısal sütunların özel istatistiklerini inceleyelim
df[sayisal_sutunlar].describe()
# Out:
#               adet   birim_fiyat  indirim_orani  kargo_ucreti  teslimat_gunu  \
# count  1398.000000   1398.000000    1398.000000   1398.000000    1398.000000
# mean      2.143062    660.712818       0.051717     39.728398       3.355508
# std       2.031849   1051.014558       0.059681     14.188925       1.771142
# min       1.000000     93.110000       0.000000      0.000000       1.000000
# 25%       1.000000    198.855000       0.000000     29.900000       2.000000
# 50%       2.000000    287.120000       0.050000     39.900000       3.000000
# 75%       3.000000    817.335000       0.100000     49.900000       4.000000
# max      38.000000  18145.230000       0.200000     59.900000      31.000000
#
#        musteri_puani  kar_marji_orani  toplam_tutar  siparis_yili  \
# count    1398.000000      1398.000000   1398.000000   1398.000000
# mean        3.997854         0.302446   1377.934642   2024.528612
# std         1.071193         0.069861   2988.042747      0.499359
# min         0.000000         0.180000     89.680000   2024.000000
# 25%         4.000000         0.243250    327.190000   2024.000000
# 50%         4.000000         0.305000    670.965000   2025.000000
# 75%         5.000000         0.362000   1393.250000   2025.000000
# max         5.000000         0.420000  63870.200000   2025.000000
#
#        siparis_ayi  siparis_gunu
# count  1398.000000   1398.000000
# mean      6.394134     15.655222
# std       3.455187      8.720828
# min       1.000000      1.000000
# 25%       3.000000      8.000000
# 50%       6.000000     16.000000
# 75%       9.000000     23.000000
# max      12.000000     31.000000

# %%
"""birim fiyat
IQR= Q3(75%) - Q1(25%)
   = 817 - 198 = 619
Üst Sınır= Q3 + k * IQR
Alt Sınır= Q1 - k* IQR
  k = 1 olsun
  Üst sınır=  817 + 619 = 1436
  Alt sınır= 198 - 619 = 139
Outlier: üst sınır ve alt sınırın dışında kalan örnekler
"""
# Out:
# 'birim fiyat\nIQR= Q3(75%) - Q1(25%)\n   = 817 - 198 = 619\nÜst Sınır= Q3 + k * IQR\nAlt Sınır= Q1 - k* IQR\n  k = 1 olsun\n  Üst sınır=  817 + 619 = 1436\n  Alt sınır= 198 - 619 = 139\nOutlier: üst sınır ve alt sınırın dışında kalan örnekler\n'

# %%
#IQR ile aykırı değer sınırlarını hesaplama
aykiri_sinirlar={}
for sutun in sayisal_sutunlar:
  Q1=df[sutun].quantile(0.25)
  Q3=df[sutun].quantile(0.75)
  IQR=Q3-Q1
  alt_sinir=Q1-1.5*IQR
  ust_sinir=Q3+1.5*IQR
  aykiri_sinirlar[sutun]={
      "q1":Q1,
      "q3":Q3,
      "iqr":IQR,
      "alt_sinir":alt_sinir,
      "ust_sinir":ust_sinir

  }

# %%
aykiri_sinirlar
# Out:
# {'adet': {'q1': np.float64(1.0),
#   'q3': np.float64(3.0),
#   'iqr': np.float64(2.0),
#   'alt_sinir': np.float64(-2.0),
#   'ust_sinir': np.float64(6.0)},
#  'birim_fiyat': {'q1': np.float64(198.85500000000002),
#   'q3': np.float64(817.335),
#   'iqr': np.float64(618.48),
#   'alt_sinir': np.float64(-728.865),
#   'ust_sinir': np.float64(1745.055)},
#  'indirim_orani': {'q1': np.float64(0.0),
#   'q3': np.float64(0.1),
#   'iqr': np.float64(0.1),
#   'alt_sinir': np.float64(-0.15000000000000002),
#   'ust_sinir': np.float64(0.25)},
#  'kargo_ucreti': {'q1': np.float64(29.9),
#   'q3': np.float64(49.9),
#   'iqr': np.float64(20.0),
#   'alt_sinir': np.float64(-0.10000000000000142),
#   'ust_sinir': np.float64(79.9)},
#  'teslimat_gunu': {'q1': np.float64(2.0),
#   'q3': np.float64(4.0),
#   'iqr': np.float64(2.0),
#   'alt_sinir': np.float64(-1.0),
#   'ust_sinir': np.float64(7.0)},
#  'musteri_puani': {'q1': np.float64(4.0),
#   'q3': np.float64(5.0),
#   'iqr': np.float64(1.0),
#   'alt_sinir': np.float64(2.5),
#   'ust_sinir': np.float64(6.5)},
#  'kar_marji_orani': {'q1': np.float64(0.24325),
#   'q3': np.float64(0.362),
#   'iqr': np.float64(0.11875),
#   'alt_sinir': np.float64(0.06512500000000002),
#   'ust_sinir': np.float64(0.540125)},
#  'toplam_tutar': {'q1': np.float64(327.19),
#   'q3': np.float64(1393.25),
#   'iqr': np.float64(1066.06),
#   'alt_sinir': np.float64(-1271.8999999999999),
#   'ust_sinir': np.float64(2992.34)},
#  'siparis_yili': {'q1': np.float64(2024.0),
#   'q3': np.float64(2025.0),
#   'iqr': np.float64(1.0),
#   'alt_sinir': np.float64(2022.5),
#   'ust_sinir': np.float64(2026.5)},
#  'siparis_ayi': {'q1': np.float64(3.0),
#   'q3': np.float64(9.0),
#   'iqr': np.float64(6.0),
#   'alt_sinir': np.float64(-6.0),
#   'ust_sinir': np.float64(18.0)},
#  'siparis_gunu': {'q1': np.float64(8.0),
#   'q3': np.float64(23.0),
#   'iqr': np.float64(15.0),
#   'alt_sinir': np.float64(-14.5),
#   'ust_sinir': np.float64(45.5)}}

# %%
#aykırı değer içeren kayıtları tespit et
aykiri_maskesi=pd.Series(False,index=df.index)
for sutun in sayisal_sutunlar:
  alt_sinir=aykiri_sinirlar[sutun]["alt_sinir"]
  ust_sinir=aykiri_sinirlar[sutun]["ust_sinir"]
  sutun_maskesi =(df[sutun]<alt_sinir) | (df[sutun]>ust_sinir)
  aykiri_maskesi=aykiri_maskesi | sutun_maskesi

# %%
aykiri_kayitlar=df[aykiri_maskesi]
aykiri_kayitlar
# Out:
#      siparis_id musteri_id       siparis_tarihi      sehir              bolge  \
# 1     SIP100837    MUS1347  2025-03-17 21:13:00  Gaziantep  Güneydoğu Anadolu
# 2     SIP100050    MUS1066  2025-06-03 12:42:00    Kayseri         İç Anadolu
# 6     SIP101351    MUS1011  2025-02-27 11:35:00   İstanbul            Marmara
# 7     SIP101172    MUS1357  2024-07-22 13:26:00     Ankara         İç Anadolu
# 8     SIP100779    MUS1354  2025-12-05 11:19:00   İstanbul            Marmara
# ...         ...        ...                  ...        ...                ...
# 1387  SIP100177    MUS1075  2024-01-29 13:59:00    Trabzon          Karadeniz
# 1389  SIP100056    MUS1238  2024-04-19 20:27:00     Ankara         İç Anadolu
# 1390  SIP101279    MUS1149  2024-08-24 08:38:00     Ankara         İç Anadolu
# 1393  SIP101093    MUS1187  2024-06-08 20:42:00   İstanbul            Marmara
# 1395  SIP101210    MUS1122  2025-03-07 09:07:00   İstanbul            Marmara
#
#         kategori              urun_adi  adet  birim_fiyat  indirim_orani  \
# 1           Spor           Dambıl Seti     2      1475.15           0.10
# 2          Kitap  İş Analitiği Rehberi     1       289.02           0.05
# 6           Ofis             Mouse Pad     3       169.47           0.05
# 7           Ofis        Mekanik Klavye     3      2344.47           0.00
# 8          Kitap        Python Notları     4       219.14           0.00
# ...          ...                   ...   ...          ...            ...
# 1387        Ofis        Mekanik Klavye     3      2169.51           0.00
# 1389       Kitap       Veri Bilimi 101     2       255.70           0.05
# 1390  Elektronik           Akıllı Saat     4      3074.80           0.15
# 1393        Spor             Yoga Matı     1       772.23           0.00
# 1395  Elektronik                Webcam     4       894.47           0.10
#
#       kargo_ucreti   odeme_turu musteri_tipi  teslimat_gunu  musteri_puani  \
# 1             29.9  Banka Kartı          VIP            4.0            1.0
# 2             29.9  Kredi Kartı       Mevcut            6.0            2.0
# 6             29.9   Havale/EFT          VIP            3.0            2.0
# 7             59.9  Kredi Kartı       Mevcut            3.0            4.0
# 8             29.9  Kredi Kartı         Yeni           18.0            5.0
# ...            ...          ...          ...            ...            ...
# 1387          39.9  Kredi Kartı       Mevcut            1.0            4.0
# 1389          59.9  Kredi Kartı       Mevcut            3.0            2.0
# 1390          39.9  Banka Kartı         Yeni            4.0            5.0
# 1393          29.9  Kredi Kartı       Mevcut            3.0            2.0
# 1395          49.9  Kredi Kartı       Mevcut            3.0            5.0
#
#      iade_durumu  kar_marji_orani  toplam_tutar  siparis_yili  siparis_ayi  \
# 1          Hayır            0.361       2685.17          2025            3
# 2          Hayır            0.348        304.47          2025            6
# 6           Evet            0.382        512.89          2025            2
# 7          Hayır            0.312       7093.31          2024            7
# 8           Evet            0.408        906.46          2025           12
# ...          ...              ...           ...           ...          ...
# 1387       Hayır            0.273       6548.43          2024            1
# 1389       Hayır            0.247        545.73          2024            4
# 1390       Hayır            0.414      10494.22          2024            8
# 1393       Hayır            0.275        802.13          2024            6
# 1395       Hayır            0.355       3269.99          2025            3
#
#       siparis_gunu haftanin_gunu
# 1               17        Monday
# 2                3       Tuesday
# 6               27      Thursday
# 7               22        Monday
# 8                5        Friday
# ...            ...           ...
# 1387            29        Monday
# 1389            19        Friday
# 1390            24      Saturday
# 1393             8      Saturday
# 1395             7        Friday
#
# [303 rows x 22 columns]

# %%
#aykırı değer sayılarını sütun bazında incele
for sutun in sayisal_sutunlar:
   alt_sinir=aykiri_sinirlar[sutun]["alt_sinir"]
   ust_sinir=aykiri_sinirlar[sutun]["ust_sinir"]
   aykiri_sayi =((df[sutun]<alt_sinir) | (df[sutun]>ust_sinir)).sum()
   print(f"{sutun}: {aykiri_sayi}" )
# Out:
# adet: 6
# birim_fiyat: 92
# indirim_orani: 0
# kargo_ucreti: 0
# teslimat_gunu: 5
# musteri_puani: 151
# kar_marji_orani: 0
# toplam_tutar: 134
# siparis_yili: 0
# siparis_ayi: 0
# siparis_gunu: 0

# %%
#aykırı değer içeren kayıtları veri setinden silme
df_temiz=df[~aykiri_maskesi].copy()
df_temiz.shape
# Out:
# (1095, 22)

# %%
#temizlenmiş veri setini kaydet
df_temiz.to_csv("e_ticaret_veri_seti_aykiri_degerler_duzenlendi.csv")

# %% [markdown]
# ## Kategorik Veri Analizi
# Amaç:
# 1. Veri setindeki kategorik sütunları incelemek ve dağılımlarını analiz etmek
# 2. Frekans, oran ve görselleştirme yöntemleri ile kategorik verileri yorumlama
# Adımlar:
# 1. Veri setini yüklemek
# 2. Kategorik sütunları belirlemek
# 3. Kategorik sütunların genel bilgisini incelemek
# 4. Her kategorik sütun için frekans analizi yapmak
# 5. Her kategorik sütun için oran analizi yapmak
# 6. En sık görülen kategorileri incele
# 7. En az görülen kategorileri incele
# 8. Belirli sütunlar üzerinde detaylı kategorik analiz
# 9. Belirli sütunlar için count plot çizdirme

# %%
import pandas as pd
import matplotlib.pyplot as plt #görselleştirme
import seaborn as sns #görselleştirme

# %%
#veri setini yükleme
df=pd.read_csv("e_ticaret_veri_seti_aykiri_degerler_duzenlendi.csv")

# %%
#kategorik sütunları belirle
kategorik_sutunlar=df.select_dtypes(include=["object"]).columns.tolist()
kategorik_sutunlar
# Out:
# ['siparis_id',
#  'musteri_id',
#  'siparis_tarihi',
#  'sehir',
#  'bolge',
#  'kategori',
#  'urun_adi',
#  'odeme_turu',
#  'musteri_tipi',
#  'iade_durumu',
#  'haftanin_gunu']

# %%
#kategorik sütunların genel bilgisinin incelenmesi
for sutun in kategorik_sutunlar:
  print(f"sutun adı: {sutun}")
  print(f"veri tipi: {df[sutun].dtype}")
  print(f"benzersiz deger: {df[sutun].nunique()}")
  print() #boş satır döndürür
# Out:
# sutun adı: siparis_id
# veri tipi: object
# benzersiz deger: 1095
#
# sutun adı: musteri_id
# veri tipi: object
# benzersiz deger: 411
#
# sutun adı: siparis_tarihi
# veri tipi: object
# benzersiz deger: 1094
#
# sutun adı: sehir
# veri tipi: object
# benzersiz deger: 14
#
# sutun adı: bolge
# veri tipi: object
# benzersiz deger: 6
#
# sutun adı: kategori
# veri tipi: object
# benzersiz deger: 6
#
# sutun adı: urun_adi
# veri tipi: object
# benzersiz deger: 28
#
# sutun adı: odeme_turu
# veri tipi: object
# benzersiz deger: 5
#
# sutun adı: musteri_tipi
# veri tipi: object
# benzersiz deger: 3
#
# sutun adı: iade_durumu
# veri tipi: object
# benzersiz deger: 2
#
# sutun adı: haftanin_gunu
# veri tipi: object
# benzersiz deger: 7

# %%
#her kategorik sutun için frekans analizi yapalım
for sutun in kategorik_sutunlar:
  print(df[sutun].value_counts())
  print()
# Out:
# siparis_id
# SIP100642    1
# SIP101125    1
# SIP100263    1
# SIP100707    1
# SIP100687    1
#             ..
# SIP100161    1
# SIP100320    1
# SIP101066    1
# SIP101295    1
# SIP100308    1
# Name: count, Length: 1095, dtype: int64
#
# musteri_id
# MUS1433    9
# MUS1360    7
# MUS1289    7
# MUS1072    6
# MUS1177    6
#           ..
# MUS1443    1
# MUS1335    1
# MUS1375    1
# MUS1239    1
# MUS1088    1
# Name: count, Length: 411, dtype: int64
#
# siparis_tarihi
# 2025-01-09 13:12:00    2
# 2025-04-30 22:18:00    1
# 2025-05-06 10:33:00    1
# 2025-04-02 08:16:00    1
# 2025-07-08 14:48:00    1
#                       ..
# 2024-12-19 19:50:00    1
# 2024-06-20 20:17:00    1
# 2024-04-14 19:49:00    1
# 2025-04-16 10:53:00    1
# 2025-08-31 15:11:00    1
# Name: count, Length: 1094, dtype: int64
#
# sehir
# İstanbul     264
# Ankara       124
# İzmir        118
# Antalya       86
# Konya         77
# Bursa         67
# Adana         63
# Gaziantep     49
# Mersin        46
# Samsun        45
# Eskişehir     45
# Trabzon       44
# Kayseri       36
# Kocaeli       31
# Name: count, dtype: int64
#
# bolge
# Marmara              350
# İç Anadolu           284
# Akdeniz              195
# Ege                  124
# Karadeniz             92
# Güneydoğu Anadolu     50
# Name: count, dtype: int64
#
# kategori
# Kitap         223
# Kozmetik      200
# Spor          186
# Ev Yaşam      184
# Ofis          162
# Elektronik    140
# Name: count, dtype: int64
#
# urun_adi
# Suluk                   51
# Powerbank               49
# Zaman Yönetimi          47
# Not Tutucu              47
# Python Notları          46
# Veri Bilimi 101         46
# Saklama Kutusu          44
# İş Analitiği Rehberi    43
# Şampuan                 41
# Girişimcilik            41
# Yüz Temizleme Jeli      41
# Nemlendirici            41
# Kalem Seti              40
# Defter Seti             40
# Serum                   40
# Direnç Bandı            39
# Termos                  38
# Güneş Kremi             37
# Yoga Matı               36
# Spor Çantası            35
# Masa Lambası            35
# Mouse Pad               35
# Kahve Kupası            34
# Webcam                  34
# Organizer               33
# Bluetooth Hoparlör      32
# Kablosuz Kulaklık       25
# Dambıl Seti             25
# Name: count, dtype: int64
#
# odeme_turu
# Kredi Kartı       583
# Banka Kartı       169
# Dijital Cüzdan    153
# Havale/EFT        111
# Kapıda Ödeme       79
# Name: count, dtype: int64
#
# musteri_tipi
# Mevcut    558
# Yeni      409
# VIP       128
# Name: count, dtype: int64
#
# iade_durumu
# Hayır    1007
# Evet       88
# Name: count, dtype: int64
#
# haftanin_gunu
# Saturday     169
# Tuesday      169
# Wednesday    163
# Thursday     157
# Sunday       150
# Monday       144
# Friday       143
# Name: count, dtype: int64

# %%
#her kategorik sütun için veri analizi yapalım
for sutun in kategorik_sutunlar:
  print((df[sutun].value_counts(normalize=True)*100).round(2)) #normalize, değeri 0 ve 1 arasına sıkıştırır.
  print()
# Out:
# siparis_id
# SIP100642    0.09
# SIP101125    0.09
# SIP100263    0.09
# SIP100707    0.09
# SIP100687    0.09
#              ...
# SIP100161    0.09
# SIP100320    0.09
# SIP101066    0.09
# SIP101295    0.09
# SIP100308    0.09
# Name: proportion, Length: 1095, dtype: float64
#
# musteri_id
# MUS1433    0.82
# MUS1360    0.64
# MUS1289    0.64
# MUS1072    0.55
# MUS1177    0.55
#            ...
# MUS1443    0.09
# MUS1335    0.09
# MUS1375    0.09
# MUS1239    0.09
# MUS1088    0.09
# Name: proportion, Length: 411, dtype: float64
#
# siparis_tarihi
# 2025-01-09 13:12:00    0.18
# 2025-04-30 22:18:00    0.09
# 2025-05-06 10:33:00    0.09
# 2025-04-02 08:16:00    0.09
# 2025-07-08 14:48:00    0.09
#                        ...
# 2024-12-19 19:50:00    0.09
# 2024-06-20 20:17:00    0.09
# 2024-04-14 19:49:00    0.09
# 2025-04-16 10:53:00    0.09
# 2025-08-31 15:11:00    0.09
# Name: proportion, Length: 1094, dtype: float64
#
# sehir
# İstanbul     24.11
# Ankara       11.32
# İzmir        10.78
# Antalya       7.85
# Konya         7.03
# Bursa         6.12
# Adana         5.75
# Gaziantep     4.47
# Mersin        4.20
# Samsun        4.11
# Eskişehir     4.11
# Trabzon       4.02
# Kayseri       3.29
# Kocaeli       2.83
# Name: proportion, dtype: float64
#
# bolge
# Marmara              31.96
# İç Anadolu           25.94
# Akdeniz              17.81
# Ege                  11.32
# Karadeniz             8.40
# Güneydoğu Anadolu     4.57
# Name: proportion, dtype: float64
#
# kategori
# Kitap         20.37
# Kozmetik      18.26
# Spor          16.99
# Ev Yaşam      16.80
# Ofis          14.79
# Elektronik    12.79
# Name: proportion, dtype: float64
#
# urun_adi
# Suluk                   4.66
# Powerbank               4.47
# Zaman Yönetimi          4.29
# Not Tutucu              4.29
# Python Notları          4.20
# Veri Bilimi 101         4.20
# Saklama Kutusu          4.02
# İş Analitiği Rehberi    3.93
# Şampuan                 3.74
# Girişimcilik            3.74
# Yüz Temizleme Jeli      3.74
# Nemlendirici            3.74
# Kalem Seti              3.65
# Defter Seti             3.65
# Serum                   3.65
# Direnç Bandı            3.56
# Termos                  3.47
# Güneş Kremi             3.38
# Yoga Matı               3.29
# Spor Çantası            3.20
# Masa Lambası            3.20
# Mouse Pad               3.20
# Kahve Kupası            3.11
# Webcam                  3.11
# Organizer               3.01
# Bluetooth Hoparlör      2.92
# Kablosuz Kulaklık       2.28
# Dambıl Seti             2.28
# Name: proportion, dtype: float64
#
# odeme_turu
# Kredi Kartı       53.24
# Banka Kartı       15.43
# Dijital Cüzdan    13.97
# Havale/EFT        10.14
# Kapıda Ödeme       7.21
# Name: proportion, dtype: float64
#
# musteri_tipi
# Mevcut    50.96
# Yeni      37.35
# VIP       11.69
# Name: proportion, dtype: float64
#
# iade_durumu
# Hayır    91.96
# Evet      8.04
# Name: proportion, dtype: float64
#
# haftanin_gunu
# Saturday     15.43
# Tuesday      15.43
# Wednesday    14.89
# Thursday     14.34
# Sunday       13.70
# Monday       13.15
# Friday       13.06
# Name: proportion, dtype: float64

# %%
#en sık görülen kategorileri inceleyelim
for sutun in kategorik_sutunlar:
  print()
  print(df[sutun].value_counts().head(3))
# Out:
# siparis_id
# SIP100642    1
# SIP101125    1
# SIP100263    1
# Name: count, dtype: int64
#
# musteri_id
# MUS1433    9
# MUS1360    7
# MUS1289    7
# Name: count, dtype: int64
#
# siparis_tarihi
# 2025-01-09 13:12:00    2
# 2025-04-30 22:18:00    1
# 2025-05-06 10:33:00    1
# Name: count, dtype: int64
#
# sehir
# İstanbul    264
# Ankara      124
# İzmir       118
# Name: count, dtype: int64
#
# bolge
# Marmara       350
# İç Anadolu    284
# Akdeniz       195
# Name: count, dtype: int64
#
# kategori
# Kitap       223
# Kozmetik    200
# Spor        186
# Name: count, dtype: int64
#
# urun_adi
# Suluk             51
# Powerbank         49
# Zaman Yönetimi    47
# Name: count, dtype: int64
#
# odeme_turu
# Kredi Kartı       583
# Banka Kartı       169
# Dijital Cüzdan    153
# Name: count, dtype: int64
#
# musteri_tipi
# Mevcut    558
# Yeni      409
# VIP       128
# Name: count, dtype: int64
#
# iade_durumu
# Hayır    1007
# Evet       88
# Name: count, dtype: int64
#
# haftanin_gunu
# Saturday     169
# Tuesday      169
# Wednesday    163
# Name: count, dtype: int64

# %%
#en az görülen kategorileri inceleyelim
for sutun in kategorik_sutunlar:
  print()
  print(df[sutun].value_counts().tail(3))
# Out:
# siparis_id
# SIP101066    1
# SIP101295    1
# SIP100308    1
# Name: count, dtype: int64
#
# musteri_id
# MUS1375    1
# MUS1239    1
# MUS1088    1
# Name: count, dtype: int64
#
# siparis_tarihi
# 2024-04-14 19:49:00    1
# 2025-04-16 10:53:00    1
# 2025-08-31 15:11:00    1
# Name: count, dtype: int64
#
# sehir
# Trabzon    44
# Kayseri    36
# Kocaeli    31
# Name: count, dtype: int64
#
# bolge
# Ege                  124
# Karadeniz             92
# Güneydoğu Anadolu     50
# Name: count, dtype: int64
#
# kategori
# Ev Yaşam      184
# Ofis          162
# Elektronik    140
# Name: count, dtype: int64
#
# urun_adi
# Bluetooth Hoparlör    32
# Kablosuz Kulaklık     25
# Dambıl Seti           25
# Name: count, dtype: int64
#
# odeme_turu
# Dijital Cüzdan    153
# Havale/EFT        111
# Kapıda Ödeme       79
# Name: count, dtype: int64
#
# musteri_tipi
# Mevcut    558
# Yeni      409
# VIP       128
# Name: count, dtype: int64
#
# iade_durumu
# Hayır    1007
# Evet       88
# Name: count, dtype: int64
#
# haftanin_gunu
# Sunday    150
# Monday    144
# Friday    143
# Name: count, dtype: int64

# %%
#belirli sütunlar üzerinde detaylı kategorik analiz
detayli_analiz_sutunları=["sehir","kategori","odeme_turu","musteri_tipi"]
for sutun in detayli_analiz_sutunları:
  if sutun in df.columns:
    print("Frekanslar")
    print(df[sutun].value_counts())
    print()

    print("Oranlar")
    print((df[sutun].value_counts(normalize=True)*100).round(2))
    print()
# Out:
# Frekanslar
# sehir
# İstanbul     264
# Ankara       124
# İzmir        118
# Antalya       86
# Konya         77
# Bursa         67
# Adana         63
# Gaziantep     49
# Mersin        46
# Samsun        45
# Eskişehir     45
# Trabzon       44
# Kayseri       36
# Kocaeli       31
# Name: count, dtype: int64
#
# Oranlar
# sehir
# İstanbul     24.11
# Ankara       11.32
# İzmir        10.78
# Antalya       7.85
# Konya         7.03
# Bursa         6.12
# Adana         5.75
# Gaziantep     4.47
# Mersin        4.20
# Samsun        4.11
# Eskişehir     4.11
# Trabzon       4.02
# Kayseri       3.29
# Kocaeli       2.83
# Name: proportion, dtype: float64
#
# Frekanslar
# kategori
# Kitap         223
# Kozmetik      200
# Spor          186
# Ev Yaşam      184
# Ofis          162
# Elektronik    140
# Name: count, dtype: int64
#
# Oranlar
# kategori
# Kitap         20.37
# Kozmetik      18.26
# Spor          16.99
# Ev Yaşam      16.80
# Ofis          14.79
# Elektronik    12.79
# Name: proportion, dtype: float64
#
# Frekanslar
# odeme_turu
# Kredi Kartı       583
# Banka Kartı       169
# Dijital Cüzdan    153
# Havale/EFT        111
# Kapıda Ödeme       79
# Name: count, dtype: int64
#
# Oranlar
# odeme_turu
# Kredi Kartı       53.24
# Banka Kartı       15.43
# Dijital Cüzdan    13.97
# Havale/EFT        10.14
# Kapıda Ödeme       7.21
# Name: proportion, dtype: float64
#
# Frekanslar
# musteri_tipi
# Mevcut    558
# Yeni      409
# VIP       128
# Name: count, dtype: int64
#
# Oranlar
# musteri_tipi
# Mevcut    50.96
# Yeni      37.35
# VIP       11.69
# Name: proportion, dtype: float64

# %%
#belirli sütunlar için count plot çizdirme
for sutun in detayli_analiz_sutunları:
  if sutun in df.columns:
    plt.figure(figsize=(6,3))
    sns.countplot(data=df,x=sutun ,order=df[sutun].value_counts().index)    #index,kategori isimlerini döndürür,sayıları döndürmez
    plt.title(f"{sutun} sütunu için count plot")
    plt.xlabel(sutun)
    plt.ylabel("Frekans")
    plt.xticks(rotation=45) # x etiketlerinin yazı açısını ayarlar
    plt.tight_layout()
    plt.show()

# %%
#oranlara göre count plot çizdirme
for sutun in detayli_analiz_sutunları:
  if sutun in df.columns:
    plt.figure(figsize=(6,3))
    sns.countplot(data=df,x=sutun,order=(df[sutun].value_counts(normalize=True)*100).round(2).index, stat='percent') #oran için stat kullandık
    plt.title(f"{sutun} sütunu için count plot")
    plt.xlabel(sutun)
    plt.ylabel("Oran")
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Sayısal Veri Analizi
# Amaç:
# 1. Veri setindeki analiz için uygun sayısal sütunları incelemek
# 2. Temel istatistikler ve histogram ile dağılım yapısını değerlendirmek
# Adımlar:
# 1. Veri setini yüklemek
# 2. Sayısal sütunları belirlemek
# 3. Analiz için uygun sayısal sütunları seçmek
# 4. Seçilen sütunların genel bilgisini incelemek
# 5. Temel istatistikleri hesapla
# 6. Histogram çizdir

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#veri setini yükleme
df=pd.read_csv("e_ticaret_veri_seti_aykiri_degerler_duzenlendi.csv")

# %%
#sayısal tipteki sütunları belirle
sayisal_sutunlar=df.select_dtypes(include=["float64","int64"]).columns.tolist()
sayisal_sutunlar
# Out:
# ['Unnamed: 0',
#  'adet',
#  'birim_fiyat',
#  'indirim_orani',
#  'kargo_ucreti',
#  'teslimat_gunu',
#  'musteri_puani',
#  'kar_marji_orani',
#  'toplam_tutar',
#  'siparis_yili',
#  'siparis_ayi',
#  'siparis_gunu']

# %%
#analiz için uygun sayısal sütunlar
analiz_sutunlari=["birim_fiyat","toplam_tutar","teslimat_gunu","musteri_puani"]

# %%
#seçilen sütunların genel bilgisini incele
for sutun in sayisal_sutunlar:
  print(f"sutun adı: {sutun}")
  print(f"veri tipi: {df[sutun].dtype}")
  print(f"benzersiz deger sayisi: {df[sutun].nunique()}")
  print()
# Out:
# sutun adı: Unnamed: 0
# veri tipi: int64
# benzersiz deger sayisi: 1095
#
# sutun adı: adet
# veri tipi: int64
# benzersiz deger sayisi: 5
#
# sutun adı: birim_fiyat
# veri tipi: float64
# benzersiz deger sayisi: 1080
#
# sutun adı: indirim_orani
# veri tipi: float64
# benzersiz deger sayisi: 5
#
# sutun adı: kargo_ucreti
# veri tipi: float64
# benzersiz deger sayisi: 5
#
# sutun adı: teslimat_gunu
# veri tipi: float64
# benzersiz deger sayisi: 7
#
# sutun adı: musteri_puani
# veri tipi: float64
# benzersiz deger sayisi: 3
#
# sutun adı: kar_marji_orani
# veri tipi: float64
# benzersiz deger sayisi: 238
#
# sutun adı: toplam_tutar
# veri tipi: float64
# benzersiz deger sayisi: 1092
#
# sutun adı: siparis_yili
# veri tipi: int64
# benzersiz deger sayisi: 2
#
# sutun adı: siparis_ayi
# veri tipi: int64
# benzersiz deger sayisi: 12
#
# sutun adı: siparis_gunu
# veri tipi: int64
# benzersiz deger sayisi: 31

# %%
#temel istatistikleri hesaplama
df[analiz_sutunlari].describe()
# Out:
#        birim_fiyat  toplam_tutar  teslimat_gunu  musteri_puani
# count  1095.000000   1095.000000    1095.000000    1095.000000
# mean    436.698950    779.359014       3.315068       4.282192
# std     363.625045    631.014875       1.441834       0.707625
# min      93.110000     89.680000       1.000000       3.000000
# 25%     192.955000    294.815000       2.000000       4.000000
# 50%     262.050000    565.580000       3.000000       4.000000
# 75%     583.895000   1017.895000       4.000000       5.000000
# max    1742.850000   2990.840000       7.000000       5.000000

# %%
#histogram çizdrime
for sutun in analiz_sutunlari:
  if sutun in df.columns:
    plt.figure(figsize=(6,3))
    plt.hist(df[sutun],bins=120) #bins değeri arttıkça grafik daha detaylı olur
    plt.title(f"{sutun} sütununun histogramı")
    plt.xlabel(sutun)
    plt.ylabel("frekans")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Grup Bazlı Analiz
# Amaç:
# 1. Veri setini farklı kırılımlara ayırarak grup bazlı analiz yapalım
# 2. groupby yapısı ile özet istatistikler üretip sonuçları yorumlamak
# Adımlar:
# 1. Veri setini yüklemek
# 2. Grup bazlı analiz için kullanılacak sütunları belirle
# 3. Kategoriye göre temel analiz
# 4. Sehre göre temel analiz
# 5. Müşteri tipine göre temel analiz
# 6. Ödeme türüne göre temel analiz
# 7. Birden fazla sütun ile grup bazlı analiz

# %%
import pandas as pd
pd.set_option("display.max_columns",None)

# %%
#veri setini yükleyelim
#grup bazlı analiz için kullanılacak sütunları belirle
df=pd.read_csv("e_ticaret_veri_seti_aykiri_degerler_duzenlendi.csv")
df.head()
# Out:
#    Unnamed: 0 siparis_id musteri_id       siparis_tarihi      sehir  \
# 0           0  SIP101125    MUS1391  2024-01-13 17:06:00   İstanbul
# 1           3  SIP100263    MUS1008  2024-08-10 15:13:00    Antalya
# 2           4  SIP100707    MUS1291  2024-08-19 08:24:00  Gaziantep
# 3           5  SIP100687    MUS1147  2025-08-09 08:42:00      Konya
# 4          10  SIP100254    MUS1447  2024-07-30 09:06:00      Konya
#
#                bolge    kategori            urun_adi  adet  birim_fiyat  \
# 0            Marmara    Kozmetik        Nemlendirici     1       414.51
# 1            Akdeniz       Kitap        Girişimcilik     5       194.78
# 2  Güneydoğu Anadolu  Elektronik           Powerbank     3       841.80
# 3         İç Anadolu    Kozmetik        Nemlendirici     2       417.02
# 4         İç Anadolu  Elektronik  Bluetooth Hoparlör     1      1327.75
#
#    indirim_orani  kargo_ucreti      odeme_turu musteri_tipi  teslimat_gunu  \
# 0           0.05          49.9     Kredi Kartı         Yeni            3.0
# 1           0.00          49.9    Kapıda Ödeme         Yeni            3.0
# 2           0.05          39.9  Dijital Cüzdan       Mevcut            4.0
# 3           0.00          59.9  Dijital Cüzdan       Mevcut            4.0
# 4           0.05          29.9     Banka Kartı       Mevcut            4.0
#
#    musteri_puani iade_durumu  kar_marji_orani  toplam_tutar  siparis_yili  \
# 0            5.0       Hayır            0.220        443.68          2024
# 1            5.0       Hayır            0.250       1023.80          2024
# 2            5.0       Hayır            0.280       2439.03          2024
# 3            5.0       Hayır            0.220        893.94          2025
# 4            5.0       Hayır            0.283       1291.26          2024
#
#    siparis_ayi  siparis_gunu haftanin_gunu
# 0            1            13      Saturday
# 1            8            10      Saturday
# 2            8            19        Monday
# 3            8             9      Saturday
# 4            7            30       Tuesday

# %%
#kategoriye göre temel analiz
kategori_analizi=df.groupby("kategori").agg(
    {
        "toplam_tutar":["count","mean","sum"],
        "birim_fiyat": "mean",
        "musteri_puani": "mean",
        "teslimat_gunu":"mean"
    }
).round(1)
kategori_analizi
# Out:
#            toplam_tutar                   birim_fiyat musteri_puani  \
#                   count    mean       sum        mean          mean
# kategori
# Elektronik          140  1520.9  212930.3      1065.5           4.2
# Ev Yaşam            184   773.6  142335.6       366.7           4.3
# Kitap               223   511.5  114075.6       224.8           4.3
# Kozmetik            200   737.6  147522.9       373.6           4.4
# Ofis                162   290.4   47051.9       138.2           4.2
# Spor                186  1018.7  189481.9       614.5           4.3
#
#            teslimat_gunu
#                     mean
# kategori
# Elektronik           3.3
# Ev Yaşam             3.4
# Kitap                3.4
# Kozmetik             3.4
# Ofis                 3.1
# Spor                 3.2

# %%
#şehre göre temel analiz yapalım
sehir_analiz=df.groupby("sehir").agg({
    "toplam_tutar":["sum","mean"],
    "teslimat_gunu":"mean",
    "musteri_puani": "mean"
}).round(1)
sehir_analiz
# Out:
#           toplam_tutar        teslimat_gunu musteri_puani
#                    sum   mean          mean          mean
# sehir
# Adana          50353.3  799.3           3.5           4.3
# Ankara         96721.1  780.0           3.1           4.2
# Antalya        63712.8  740.8           3.5           4.3
# Bursa          46782.8  698.3           3.5           4.2
# Eskişehir      37550.0  834.4           3.2           4.2
# Gaziantep      35240.3  719.2           3.4           4.3
# Kayseri        24878.8  691.1           3.6           4.3
# Kocaeli        21293.0  686.9           3.3           4.2
# Konya          59424.3  771.7           3.3           4.4
# Mersin         38043.9  827.0           3.5           4.2
# Samsun         36263.5  805.9           3.3           4.4
# Trabzon        30395.2  690.8           3.4           4.2
# İstanbul      224020.6  848.6           3.3           4.4
# İzmir          88718.5  751.9           3.1           4.2

# %%
#müşteri tipine göre temel analiz
musteri_tipi_analizi=df.groupby("musteri_tipi").agg({
    "toplam_tutar":["sum","mean"],
    "teslimat_gunu":"mean",
    "musteri_puani":"mean"
}
).round(1)
musteri_tipi_analizi
# Out:
#              toplam_tutar        teslimat_gunu musteri_puani
#                       sum   mean          mean          mean
# musteri_tipi
# Mevcut           442921.1  793.8           3.3           4.3
# VIP              107110.0  836.8           3.4           4.3
# Yeni             303367.0  741.7           3.3           4.3

# %%
#ödeme türüne göre temel analiz
odeme_turu_analiz=df.groupby("odeme_turu").agg({
    "toplam_tutar":["sum","mean"],
    "teslimat_gunu":"mean",
    "musteri_puani":"mean"
}).round(1)
odeme_turu_analiz
# Out:
#                toplam_tutar        teslimat_gunu musteri_puani
#                         sum   mean          mean          mean
# odeme_turu
# Banka Kartı        143011.1  846.2           3.5           4.2
# Dijital Cüzdan     129911.2  849.1           3.3           4.3
# Havale/EFT          92894.5  836.9           3.1           4.2
# Kapıda Ödeme        48113.2  609.0           3.2           4.4
# Kredi Kartı        439468.2  753.8           3.3           4.3

# %%
#birden fazla sütun ile grup bazlı analiz
kategori_musteri_tipi_analiz=df.groupby(["kategori","musteri_tipi"]).agg({
    "toplam_tutar":["sum","mean"],
    "musteri_puani":"mean",
    "teslimat_gunu":"mean"
}).round(1)
kategori_musteri_tipi_analiz
# Out:
#                         toplam_tutar         musteri_puani teslimat_gunu
#                                  sum    mean          mean          mean
# kategori   musteri_tipi
# Elektronik Mevcut           122623.6  1592.5           4.3           3.4
#            VIP               26459.9  1392.6           4.0           3.2
#            Yeni              63846.8  1451.1           4.2           3.3
# Ev Yaşam   Mevcut            76611.8   798.0           4.3           3.5
#            VIP               18428.6   837.7           4.3           3.5
#            Yeni              47295.1   716.6           4.2           3.4
# Kitap      Mevcut            53918.5   481.4           4.3           3.5
#            VIP               15604.2   577.9           4.1           3.6
#            Yeni              44552.8   530.4           4.2           3.2
# Kozmetik   Mevcut            80644.4   720.0           4.3           3.4
#            VIP               20325.0   725.9           4.5           3.8
#            Yeni              46553.4   775.9           4.6           3.1
# Ofis       Mevcut            19900.3   276.4           4.3           3.1
#            VIP                3538.3   252.7           4.1           2.6
#            Yeni              23613.4   310.7           4.2           3.3
# Spor       Mevcut            89222.5  1002.5           4.3           3.1
#            VIP               22753.9  1264.1           4.4           3.0
#            Yeni              77505.5   981.1           4.2           3.3

# %% [markdown]
# ## Pivot Tablo Analizi
# Amaç:
# 1. Veri setini iki yönli kırılımlar ile özetleyerek pivot tablo mantığını kavramak
# 2. Pivot tablo ile karşılaştırmalı analizler ve sonuçların yorumlanması
# Adımlar:
# 1. veri setini yükle
# 2. Kategori ve müşteri tipine göre pivot tablo analizi
# 3. Şehir ve ödeme türüne göre pivot tablo analizi
# 4. Kategori ve ödeme türüne göre pivot tablo analizi
# 5. Şehir ve müşteri tipine göre pivot tablo analizi

# %%
import pandas as pd

# %%
#veri setini yükle
df=pd.read_csv("e_ticaret_veri_seti_aykiri_degerler_duzenlendi.csv")
df.head()
# Out:
#    Unnamed: 0 siparis_id musteri_id       siparis_tarihi      sehir  \
# 0           0  SIP101125    MUS1391  2024-01-13 17:06:00   İstanbul
# 1           3  SIP100263    MUS1008  2024-08-10 15:13:00    Antalya
# 2           4  SIP100707    MUS1291  2024-08-19 08:24:00  Gaziantep
# 3           5  SIP100687    MUS1147  2025-08-09 08:42:00      Konya
# 4          10  SIP100254    MUS1447  2024-07-30 09:06:00      Konya
#
#                bolge    kategori            urun_adi  adet  birim_fiyat  \
# 0            Marmara    Kozmetik        Nemlendirici     1       414.51
# 1            Akdeniz       Kitap        Girişimcilik     5       194.78
# 2  Güneydoğu Anadolu  Elektronik           Powerbank     3       841.80
# 3         İç Anadolu    Kozmetik        Nemlendirici     2       417.02
# 4         İç Anadolu  Elektronik  Bluetooth Hoparlör     1      1327.75
#
#    indirim_orani  kargo_ucreti      odeme_turu musteri_tipi  teslimat_gunu  \
# 0           0.05          49.9     Kredi Kartı         Yeni            3.0
# 1           0.00          49.9    Kapıda Ödeme         Yeni            3.0
# 2           0.05          39.9  Dijital Cüzdan       Mevcut            4.0
# 3           0.00          59.9  Dijital Cüzdan       Mevcut            4.0
# 4           0.05          29.9     Banka Kartı       Mevcut            4.0
#
#    musteri_puani iade_durumu  kar_marji_orani  toplam_tutar  siparis_yili  \
# 0            5.0       Hayır            0.220        443.68          2024
# 1            5.0       Hayır            0.250       1023.80          2024
# 2            5.0       Hayır            0.280       2439.03          2024
# 3            5.0       Hayır            0.220        893.94          2025
# 4            5.0       Hayır            0.283       1291.26          2024
#
#    siparis_ayi  siparis_gunu haftanin_gunu
# 0            1            13      Saturday
# 1            8            10      Saturday
# 2            8            19        Monday
# 3            8             9      Saturday
# 4            7            30       Tuesday

# %%
#kategori ve müşteri tipine göre pivot tablo analizi
#her kategori için müşteri tiplerine göre ortalama toplam tutar
#elektronik -> yeni
pivot_kategori_musteri=pd.pivot_table(
    df,
    index="kategori",
    columns="musteri_tipi",
    values="toplam_tutar",
    aggfunc="mean"
).round(1)
pivot_kategori_musteri
# Out:
# musteri_tipi  Mevcut     VIP    Yeni
# kategori
# Elektronik    1592.5  1392.6  1451.1
# Ev Yaşam       798.0   837.7   716.6
# Kitap          481.4   577.9   530.4
# Kozmetik       720.0   725.9   775.9
# Ofis           276.4   252.7   310.7
# Spor          1002.5  1264.1   981.1

# %%
#şehir ve ödeme türüne göre pivot tablo analizi
pivot_sehir_odeme_turu=pd.pivot_table(
    df,
    index="sehir",
    columns="odeme_turu",
    values="toplam_tutar",
    aggfunc="sum"
).round(1)
pivot_sehir_odeme_turu
# Out:
# odeme_turu  Banka Kartı  Dijital Cüzdan  Havale/EFT  Kapıda Ödeme  Kredi Kartı
# sehir
# Adana            9186.0          9134.0      5565.5        2466.4      24001.3
# Ankara          13764.1         13798.7     12892.8        7329.5      48936.1
# Antalya         10871.3          7115.7      6658.0        5511.6      33556.2
# Bursa            3694.8          8030.9      5853.7        6095.0      23108.3
# Eskişehir        4313.3          8010.6       707.9        3395.3      21122.9
# Gaziantep        4930.2          7119.0      3746.8        1395.0      18049.3
# Kayseri          2957.4          2655.7      6466.2        3307.6       9491.8
# Kocaeli          1579.2          5792.3      2891.3        2839.0       8191.2
# Konya           15601.8          9379.3      4163.0        2611.8      27668.4
# Mersin           9461.5          4307.8      2454.0         153.2      21667.4
# Samsun           5068.7          9928.5      3619.5         177.3      17469.5
# Trabzon          6164.2          2179.8      4533.4           NaN      17517.8
# İstanbul        45163.2         28373.6     24956.5        5937.2     119590.0
# İzmir           10255.4         14085.4      8385.8        6894.2      49097.9

# %%
#kategori ve ödeme türüne göre pivot tablo analizi
pivot_kategori_odeme=pd.pivot_table(
    df,
    index="kategori",
    columns="odeme_turu",
    values="musteri_puani",
    aggfunc="mean"
).round(2)
pivot_kategori_odeme
# Out:
# odeme_turu  Banka Kartı  Dijital Cüzdan  Havale/EFT  Kapıda Ödeme  Kredi Kartı
# kategori
# Elektronik         4.04            4.25        4.28          4.43         4.28
# Ev Yaşam           4.16            4.23        4.00          4.21         4.36
# Kitap              4.25            4.22        4.00          4.62         4.27
# Kozmetik           4.48            4.33        4.36          4.53         4.41
# Ofis               4.29            4.15        4.30          4.31         4.23
# Spor               4.20            4.39        4.07          4.15         4.28

# %%
#şehir ve müşteri tipine göre pivot tablo analizi
pivot_sehir_musteri=pd.pivot_table(
    df,
    index="sehir",
    columns="musteri_tipi",
    values="kargo_ucreti",
    aggfunc="mean"
).round(2)
pivot_sehir_musteri
# Out:
# musteri_tipi  Mevcut    VIP   Yeni
# sehir
# Adana          40.16  34.92  42.12
# Ankara         41.82  37.06  39.91
# Antalya        38.63  36.57  40.19
# Bursa          38.62  39.90  40.23
# Eskişehir      36.38  39.90  39.04
# Gaziantep      38.66  45.61  41.58
# Kayseri        43.37  45.90  41.90
# Kocaeli        42.63  46.57  40.49
# Konya          38.12  35.92  39.90
# Mersin         40.68  39.90  41.02
# Samsun         39.49  37.90  36.78
# Trabzon        34.91  35.90  44.02
# İstanbul       39.09  39.60  36.72
# İzmir          42.21  38.42  37.52

# %% [markdown]
# ## Veri Görselleştirme
# Amaç:
# 1. Veri setindeki farklı değişkenleri uygun grafik türüyle görselleştirmek
# 2. Grafikler üzerinden zaman değişimi, ilişki, karşılaştırma ve dağılım yapısını incelemek
# Adımlar:
# 1. Veri setini yüklemek
# 2. Line plot ile zaman içindeki değişimi görselleştirmek
# 3. Scatter plot ile iki sayısal değişken arasındaki ilişkiyi görselleştirmek
# 4. Bar plot ile karşılaştırmalı görselleştirme yapmak
# 5. Histogram ile sayısal dağılım görselleştirmek
# 6. Box plot ile dağılım ve aykırı değer tespiti

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_theme()

# %%
#veri setini yükleme
df=pd.read_csv("e_ticaret_veri_seti_aykiri_degerler_duzenlendi.csv")
df.head()
# Out:
#    Unnamed: 0 siparis_id musteri_id       siparis_tarihi      sehir  \
# 0           0  SIP101125    MUS1391  2024-01-13 17:06:00   İstanbul
# 1           3  SIP100263    MUS1008  2024-08-10 15:13:00    Antalya
# 2           4  SIP100707    MUS1291  2024-08-19 08:24:00  Gaziantep
# 3           5  SIP100687    MUS1147  2025-08-09 08:42:00      Konya
# 4          10  SIP100254    MUS1447  2024-07-30 09:06:00      Konya
#
#                bolge    kategori            urun_adi  adet  birim_fiyat  \
# 0            Marmara    Kozmetik        Nemlendirici     1       414.51
# 1            Akdeniz       Kitap        Girişimcilik     5       194.78
# 2  Güneydoğu Anadolu  Elektronik           Powerbank     3       841.80
# 3         İç Anadolu    Kozmetik        Nemlendirici     2       417.02
# 4         İç Anadolu  Elektronik  Bluetooth Hoparlör     1      1327.75
#
#    indirim_orani  kargo_ucreti      odeme_turu musteri_tipi  teslimat_gunu  \
# 0           0.05          49.9     Kredi Kartı         Yeni            3.0
# 1           0.00          49.9    Kapıda Ödeme         Yeni            3.0
# 2           0.05          39.9  Dijital Cüzdan       Mevcut            4.0
# 3           0.00          59.9  Dijital Cüzdan       Mevcut            4.0
# 4           0.05          29.9     Banka Kartı       Mevcut            4.0
#
#    musteri_puani iade_durumu  kar_marji_orani  toplam_tutar  siparis_yili  \
# 0            5.0       Hayır            0.220        443.68          2024
# 1            5.0       Hayır            0.250       1023.80          2024
# 2            5.0       Hayır            0.280       2439.03          2024
# 3            5.0       Hayır            0.220        893.94          2025
# 4            5.0       Hayır            0.283       1291.26          2024
#
#    siparis_ayi  siparis_gunu haftanin_gunu
# 0            1            13      Saturday
# 1            8            10      Saturday
# 2            8            19        Monday
# 3            8             9      Saturday
# 4            7            30       Tuesday

# %%
#line plot ile zaman içindeki değişimi görselleştirelim
#sipariş tarihini datetime'a çevirelim
df["siparis_tarihi"]=pd.to_datetime(df["siparis_tarihi"])
df["siparis_ayi"]=df["siparis_tarihi"].dt.month
df.head()
# Out:
#    Unnamed: 0 siparis_id musteri_id      siparis_tarihi      sehir  \
# 0           0  SIP101125    MUS1391 2024-01-13 17:06:00   İstanbul
# 1           3  SIP100263    MUS1008 2024-08-10 15:13:00    Antalya
# 2           4  SIP100707    MUS1291 2024-08-19 08:24:00  Gaziantep
# 3           5  SIP100687    MUS1147 2025-08-09 08:42:00      Konya
# 4          10  SIP100254    MUS1447 2024-07-30 09:06:00      Konya
#
#                bolge    kategori            urun_adi  adet  birim_fiyat  \
# 0            Marmara    Kozmetik        Nemlendirici     1       414.51
# 1            Akdeniz       Kitap        Girişimcilik     5       194.78
# 2  Güneydoğu Anadolu  Elektronik           Powerbank     3       841.80
# 3         İç Anadolu    Kozmetik        Nemlendirici     2       417.02
# 4         İç Anadolu  Elektronik  Bluetooth Hoparlör     1      1327.75
#
#    indirim_orani  kargo_ucreti      odeme_turu musteri_tipi  teslimat_gunu  \
# 0           0.05          49.9     Kredi Kartı         Yeni            3.0
# 1           0.00          49.9    Kapıda Ödeme         Yeni            3.0
# 2           0.05          39.9  Dijital Cüzdan       Mevcut            4.0
# 3           0.00          59.9  Dijital Cüzdan       Mevcut            4.0
# 4           0.05          29.9     Banka Kartı       Mevcut            4.0
#
#    musteri_puani iade_durumu  kar_marji_orani  toplam_tutar  siparis_yili  \
# 0            5.0       Hayır            0.220        443.68          2024
# 1            5.0       Hayır            0.250       1023.80          2024
# 2            5.0       Hayır            0.280       2439.03          2024
# 3            5.0       Hayır            0.220        893.94          2025
# 4            5.0       Hayır            0.283       1291.26          2024
#
#    siparis_ayi  siparis_gunu haftanin_gunu
# 0            1            13      Saturday
# 1            8            10      Saturday
# 2            8            19        Monday
# 3            8             9      Saturday
# 4            7            30       Tuesday

# %%
aylik_toplam_tutar=df.groupby("siparis_ayi")["toplam_tutar"].sum().reset_index()
aylik_toplam_tutar
# Out:
#     siparis_ayi  toplam_tutar
# 0             1      68309.45
# 1             2      67984.01
# 2             3      70857.89
# 3             4      68630.39
# 4             5      92213.41
# 5             6      77526.88
# 6             7      68774.62
# 7             8      55945.11
# 8             9      80591.62
# 9            10      60860.45
# 10           11      62337.84
# 11           12      79366.45

# %%
plt.figure(figsize=(10,5))
plt.plot(aylik_toplam_tutar["siparis_ayi"],aylik_toplam_tutar["toplam_tutar"],marker= "o") #line plot
plt.title("Aylara göre toplam tutar")
plt.xlabel("aylar")
plt.ylabel("toplam tutar")
plt.xticks(aylik_toplam_tutar["siparis_ayi"])
plt.tight_layout()
plt.show()

# %%
#scatter plot ile iki sayısal değişken arasındaki ilişkiyi görselleştirelim
plt.figure(figsize=(10,5))
plt.scatter(df["birim_fiyat"],df["toplam_tutar"],s=5,color="red",alpha=0.6)
plt.title("birim fiyat ve toplam tutar ilişkisi")
plt.xlabel("birim fiyat")
plt.ylabel("toplam fiyat")
plt.show()

# %%
#bar plot ile karşılaştırmalı görselleştirme
#kategoriye göre toplam tutarı toplayıp bar plot ile görselleştirme
kategori_toplam_tutar=(
    df.groupby("kategori")["toplam_tutar"].sum()
    .sort_values(ascending=False)
    .reset_index()
)
kategori_toplam_tutar
# Out:
#      kategori  toplam_tutar
# 0  Elektronik     212930.29
# 1        Spor     189481.91
# 2    Kozmetik     147522.90
# 3    Ev Yaşam     142335.55
# 4       Kitap     114075.59
# 5        Ofis      47051.88

# %%
plt.figure(figsize=(10,5))
sns.barplot(data=kategori_toplam_tutar,x="kategori",y="toplam_tutar")
plt.title("kategoriye göre toplam tutar")
plt.xlabel("kategori")
plt.ylabel("toplam tutar")
plt.xticks(rotation=45)
plt.show()

# %%
#histogram ile sayısal dağılım görelleştirme
plt.figure(figsize=(10,5))
plt.hist(df["toplam_tutar"],bins=150)
plt.title("toplam tutar dağılımı")
plt.xlabel("toplam tutar")
plt.ylabel("frekans")
plt.show()

# %%
#box plot ile dağılım ve otulier tespiti
plt.figure(figsize=(10,5))
sns.boxplot(data=df,x="kategori",y="toplam_tutar")
plt.xlabel("kategori")
plt.ylabel("toplam tutar")
plt.title("kategoriye göre toplam tutar dağılımı")
plt.show()

# %% [markdown]
# ## Zaman Serisi Analizi
# Amaç:
# 1. Veri setindeki tarih bilgisini kullanarak zaman bazlı analiz yapmak
# Adımlar:
# 1. Veri setini yüklemek
# 2. Sipariş tarihini datetime tipine dönüştür
# 3. Tarih sütunundan zaman özellikleri türet
# 4. Aylara göre sipariş yoğunluğunu incele
# 5. Ayın ilk yarısı ve ikinci yarısında ki harcama farkını incele
# 6. Hafta içi ve hafta sonu sipariş davranışlarını karşılaştırma
# 7. İki haftalık dönemlerde ortalama sipariş tutarı inceleme

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#veri setinin yüklenmesi
df=pd.read_csv("e_ticaret_veri_seti_aykiri_degerler_duzenlendi.csv")
df.head()
# Out:
#    Unnamed: 0 siparis_id musteri_id       siparis_tarihi      sehir  \
# 0           0  SIP101125    MUS1391  2024-01-13 17:06:00   İstanbul
# 1           3  SIP100263    MUS1008  2024-08-10 15:13:00    Antalya
# 2           4  SIP100707    MUS1291  2024-08-19 08:24:00  Gaziantep
# 3           5  SIP100687    MUS1147  2025-08-09 08:42:00      Konya
# 4          10  SIP100254    MUS1447  2024-07-30 09:06:00      Konya
#
#                bolge    kategori            urun_adi  adet  birim_fiyat  \
# 0            Marmara    Kozmetik        Nemlendirici     1       414.51
# 1            Akdeniz       Kitap        Girişimcilik     5       194.78
# 2  Güneydoğu Anadolu  Elektronik           Powerbank     3       841.80
# 3         İç Anadolu    Kozmetik        Nemlendirici     2       417.02
# 4         İç Anadolu  Elektronik  Bluetooth Hoparlör     1      1327.75
#
#    indirim_orani  kargo_ucreti      odeme_turu musteri_tipi  teslimat_gunu  \
# 0           0.05          49.9     Kredi Kartı         Yeni            3.0
# 1           0.00          49.9    Kapıda Ödeme         Yeni            3.0
# 2           0.05          39.9  Dijital Cüzdan       Mevcut            4.0
# 3           0.00          59.9  Dijital Cüzdan       Mevcut            4.0
# 4           0.05          29.9     Banka Kartı       Mevcut            4.0
#
#    musteri_puani iade_durumu  kar_marji_orani  toplam_tutar  siparis_yili  \
# 0            5.0       Hayır            0.220        443.68          2024
# 1            5.0       Hayır            0.250       1023.80          2024
# 2            5.0       Hayır            0.280       2439.03          2024
# 3            5.0       Hayır            0.220        893.94          2025
# 4            5.0       Hayır            0.283       1291.26          2024
#
#    siparis_ayi  siparis_gunu haftanin_gunu
# 0            1            13      Saturday
# 1            8            10      Saturday
# 2            8            19        Monday
# 3            8             9      Saturday
# 4            7            30       Tuesday

# %%
#sipariş tarihini datetime tipine dönüştür
df["siparis_tarihi"]=pd.to_datetime(df["siparis_tarihi"])
df["siparis_tarihi"].dtype
# Out:
# dtype('<M8[ns]')

# %%
#tarih sütunundan zaman özelliklerini üretme
df["siparis_yili"]=df["siparis_tarihi"].dt.year
df["siparis_ayi"]=df["siparis_tarihi"].dt.month
df["siparis_gunu"]=df["siparis_tarihi"].dt.day
df["haftanin_gunu"]=df["siparis_tarihi"].dt.day_name()
df["hafta_numarasi"]=df["siparis_tarihi"].dt.isocalendar().week.astype(int)
df.head()
# Out:
#    Unnamed: 0 siparis_id musteri_id      siparis_tarihi      sehir  \
# 0           0  SIP101125    MUS1391 2024-01-13 17:06:00   İstanbul
# 1           3  SIP100263    MUS1008 2024-08-10 15:13:00    Antalya
# 2           4  SIP100707    MUS1291 2024-08-19 08:24:00  Gaziantep
# 3           5  SIP100687    MUS1147 2025-08-09 08:42:00      Konya
# 4          10  SIP100254    MUS1447 2024-07-30 09:06:00      Konya
#
#                bolge    kategori            urun_adi  adet  birim_fiyat  \
# 0            Marmara    Kozmetik        Nemlendirici     1       414.51
# 1            Akdeniz       Kitap        Girişimcilik     5       194.78
# 2  Güneydoğu Anadolu  Elektronik           Powerbank     3       841.80
# 3         İç Anadolu    Kozmetik        Nemlendirici     2       417.02
# 4         İç Anadolu  Elektronik  Bluetooth Hoparlör     1      1327.75
#
#    indirim_orani  kargo_ucreti      odeme_turu musteri_tipi  teslimat_gunu  \
# 0           0.05          49.9     Kredi Kartı         Yeni            3.0
# 1           0.00          49.9    Kapıda Ödeme         Yeni            3.0
# 2           0.05          39.9  Dijital Cüzdan       Mevcut            4.0
# 3           0.00          59.9  Dijital Cüzdan       Mevcut            4.0
# 4           0.05          29.9     Banka Kartı       Mevcut            4.0
#
#    musteri_puani iade_durumu  kar_marji_orani  toplam_tutar  siparis_yili  \
# 0            5.0       Hayır            0.220        443.68          2024
# 1            5.0       Hayır            0.250       1023.80          2024
# 2            5.0       Hayır            0.280       2439.03          2024
# 3            5.0       Hayır            0.220        893.94          2025
# 4            5.0       Hayır            0.283       1291.26          2024
#
#    siparis_ayi  siparis_gunu haftanin_gunu  hafta_numarasi
# 0            1            13      Saturday               2
# 1            8            10      Saturday              32
# 2            8            19        Monday              34
# 3            8             9      Saturday              32
# 4            7            30       Tuesday              31

# %%
#aylara göre sipariş yoğunluğu
aylik_yogunluk=(df.groupby("siparis_ayi").agg(
  siparis_sayisi=("siparis_id","count"),
  benzersiz_musteri_sayisi=("musteri_id","nunique")
).reset_index()
 .sort_values("siparis_ayi")
    )
aylik_yogunluk
# Out:
#     siparis_ayi  siparis_sayisi  benzersiz_musteri_sayisi
# 0             1              97                        89
# 1             2              84                        75
# 2             3              94                        81
# 3             4             111                        94
# 4             5             102                        94
# 5             6              85                        77
# 6             7              79                        71
# 7             8              80                        71
# 8             9              91                        83
# 9            10              89                        80
# 10           11              86                        77
# 11           12              97                        88

# %%
plt.figure(figsize=(8,3))
plt.plot(aylik_yogunluk["siparis_ayi"],aylik_yogunluk["siparis_sayisi"], marker= "o",color="red",label="siparis_sayisi")
plt.plot(aylik_yogunluk["siparis_ayi"],aylik_yogunluk["benzersiz_musteri_sayisi"], marker= "o",color="green",label="benzersiz_musteri_sayisi")
plt.title("aylara göre sipariş yoğunluğu ve benzersiz müşteri sayısı")
plt.ylabel("sipariş sayısı ve benzersiz müşteri sayısı")
plt.xlabel("aylar")
plt.xticks(aylik_yogunluk["siparis_ayi"])
plt.legend()
plt.show()

# %%
#ayın ilk yarısı ve ikinci yarısındaki harcama farkını inceleme
#ayın ilk yarısını ve ikinci yarısını bulma
df["ay_donemi"]=df["siparis_gunu"].apply(
    lambda x: "Ayın ilk yarısı " if x<=15 else "Ayın ikinci yarısı"
)
df.head()
# Out:
#    Unnamed: 0 siparis_id musteri_id      siparis_tarihi      sehir  \
# 0           0  SIP101125    MUS1391 2024-01-13 17:06:00   İstanbul
# 1           3  SIP100263    MUS1008 2024-08-10 15:13:00    Antalya
# 2           4  SIP100707    MUS1291 2024-08-19 08:24:00  Gaziantep
# 3           5  SIP100687    MUS1147 2025-08-09 08:42:00      Konya
# 4          10  SIP100254    MUS1447 2024-07-30 09:06:00      Konya
#
#                bolge    kategori            urun_adi  adet  birim_fiyat  \
# 0            Marmara    Kozmetik        Nemlendirici     1       414.51
# 1            Akdeniz       Kitap        Girişimcilik     5       194.78
# 2  Güneydoğu Anadolu  Elektronik           Powerbank     3       841.80
# 3         İç Anadolu    Kozmetik        Nemlendirici     2       417.02
# 4         İç Anadolu  Elektronik  Bluetooth Hoparlör     1      1327.75
#
#    indirim_orani  kargo_ucreti      odeme_turu musteri_tipi  teslimat_gunu  \
# 0           0.05          49.9     Kredi Kartı         Yeni            3.0
# 1           0.00          49.9    Kapıda Ödeme         Yeni            3.0
# 2           0.05          39.9  Dijital Cüzdan       Mevcut            4.0
# 3           0.00          59.9  Dijital Cüzdan       Mevcut            4.0
# 4           0.05          29.9     Banka Kartı       Mevcut            4.0
#
#    musteri_puani iade_durumu  kar_marji_orani  toplam_tutar  siparis_yili  \
# 0            5.0       Hayır            0.220        443.68          2024
# 1            5.0       Hayır            0.250       1023.80          2024
# 2            5.0       Hayır            0.280       2439.03          2024
# 3            5.0       Hayır            0.220        893.94          2025
# 4            5.0       Hayır            0.283       1291.26          2024
#
#    siparis_ayi  siparis_gunu haftanin_gunu  hafta_numarasi           ay_donemi
# 0            1            13      Saturday               2    Ayın ilk yarısı
# 1            8            10      Saturday              32    Ayın ilk yarısı
# 2            8            19        Monday              34  Ayın ikinci yarısı
# 3            8             9      Saturday              32    Ayın ilk yarısı
# 4            7            30       Tuesday              31  Ayın ikinci yarısı

# %%
ay_donemi_analizi=(
    df.groupby("ay_donemi")
    .agg(
        toplam_tutar=("toplam_tutar","sum")
    )
    .round(1)
    .reset_index()

)
ay_donemi_analizi
# Out:
#             ay_donemi  toplam_tutar
# 0  Ayın ikinci yarısı      413476.0
# 1    Ayın ilk yarısı       439922.1

# %%
plt.figure()
sns.barplot(data=ay_donemi_analizi,x="ay_donemi",y="toplam_tutar")
plt.title("ayın ilk ve ikinci yarısına göre toplam tutar analizi")
plt.xlabel("ay dönemi")
plt.ylabel("toplam tutar")
plt.show()

# %%
#hafta içi ve hafta sonu sipariş davranışlarını karşılaştırma
df["hafta_tipi"]=df["siparis_tarihi"].dt.dayofweek.apply(
    lambda x: "haftasonu" if x>=5 else "haftaiçi"

)
df.head()
# Out:
#    Unnamed: 0 siparis_id musteri_id      siparis_tarihi      sehir  \
# 0           0  SIP101125    MUS1391 2024-01-13 17:06:00   İstanbul
# 1           3  SIP100263    MUS1008 2024-08-10 15:13:00    Antalya
# 2           4  SIP100707    MUS1291 2024-08-19 08:24:00  Gaziantep
# 3           5  SIP100687    MUS1147 2025-08-09 08:42:00      Konya
# 4          10  SIP100254    MUS1447 2024-07-30 09:06:00      Konya
#
#                bolge    kategori            urun_adi  adet  birim_fiyat  \
# 0            Marmara    Kozmetik        Nemlendirici     1       414.51
# 1            Akdeniz       Kitap        Girişimcilik     5       194.78
# 2  Güneydoğu Anadolu  Elektronik           Powerbank     3       841.80
# 3         İç Anadolu    Kozmetik        Nemlendirici     2       417.02
# 4         İç Anadolu  Elektronik  Bluetooth Hoparlör     1      1327.75
#
#    indirim_orani  kargo_ucreti      odeme_turu musteri_tipi  teslimat_gunu  \
# 0           0.05          49.9     Kredi Kartı         Yeni            3.0
# 1           0.00          49.9    Kapıda Ödeme         Yeni            3.0
# 2           0.05          39.9  Dijital Cüzdan       Mevcut            4.0
# 3           0.00          59.9  Dijital Cüzdan       Mevcut            4.0
# 4           0.05          29.9     Banka Kartı       Mevcut            4.0
#
#    musteri_puani iade_durumu  kar_marji_orani  toplam_tutar  siparis_yili  \
# 0            5.0       Hayır            0.220        443.68          2024
# 1            5.0       Hayır            0.250       1023.80          2024
# 2            5.0       Hayır            0.280       2439.03          2024
# 3            5.0       Hayır            0.220        893.94          2025
# 4            5.0       Hayır            0.283       1291.26          2024
#
#    siparis_ayi  siparis_gunu haftanin_gunu  hafta_numarasi  \
# 0            1            13      Saturday               2
# 1            8            10      Saturday              32
# 2            8            19        Monday              34
# 3            8             9      Saturday              32
# 4            7            30       Tuesday              31
#
#             ay_donemi hafta_tipi
# 0    Ayın ilk yarısı   haftasonu
# 1    Ayın ilk yarısı   haftasonu
# 2  Ayın ikinci yarısı   haftaiçi
# 3    Ayın ilk yarısı   haftasonu
# 4  Ayın ikinci yarısı   haftaiçi

# %%
hafta_tipi_analizi=(
    df.groupby("hafta_tipi")
    .agg(
        ortalama_siparis_tutari=("toplam_tutar","mean")
        )
    .round(1)
    .reset_index()
)
hafta_tipi_analizi
# Out:
#   hafta_tipi  ortalama_siparis_tutari
# 0   haftaiçi                    784.4
# 1  haftasonu                    767.1

# %%
plt.figure()
sns.barplot(data=hafta_tipi_analizi,x="hafta_tipi",y="ortalama_siparis_tutari")
plt.title("hafta içi ve hafta sonu ortalama siparis tutarı")
plt.xlabel("hafta tipi")
plt.ylabel("ortalama sipariş tutarı")
plt.show()

# %%
#iki haftalık dönemlerde ortalama sipariş tutarı
df["iki_haftalik_donem"]=((df["hafta_numarasi"]-1)//2)+1
df.head()
# Out:
#    Unnamed: 0 siparis_id musteri_id      siparis_tarihi      sehir  \
# 0           0  SIP101125    MUS1391 2024-01-13 17:06:00   İstanbul
# 1           3  SIP100263    MUS1008 2024-08-10 15:13:00    Antalya
# 2           4  SIP100707    MUS1291 2024-08-19 08:24:00  Gaziantep
# 3           5  SIP100687    MUS1147 2025-08-09 08:42:00      Konya
# 4          10  SIP100254    MUS1447 2024-07-30 09:06:00      Konya
#
#                bolge    kategori            urun_adi  adet  birim_fiyat  \
# 0            Marmara    Kozmetik        Nemlendirici     1       414.51
# 1            Akdeniz       Kitap        Girişimcilik     5       194.78
# 2  Güneydoğu Anadolu  Elektronik           Powerbank     3       841.80
# 3         İç Anadolu    Kozmetik        Nemlendirici     2       417.02
# 4         İç Anadolu  Elektronik  Bluetooth Hoparlör     1      1327.75
#
#    indirim_orani  kargo_ucreti      odeme_turu musteri_tipi  teslimat_gunu  \
# 0           0.05          49.9     Kredi Kartı         Yeni            3.0
# 1           0.00          49.9    Kapıda Ödeme         Yeni            3.0
# 2           0.05          39.9  Dijital Cüzdan       Mevcut            4.0
# 3           0.00          59.9  Dijital Cüzdan       Mevcut            4.0
# 4           0.05          29.9     Banka Kartı       Mevcut            4.0
#
#    musteri_puani iade_durumu  kar_marji_orani  toplam_tutar  siparis_yili  \
# 0            5.0       Hayır            0.220        443.68          2024
# 1            5.0       Hayır            0.250       1023.80          2024
# 2            5.0       Hayır            0.280       2439.03          2024
# 3            5.0       Hayır            0.220        893.94          2025
# 4            5.0       Hayır            0.283       1291.26          2024
#
#    siparis_ayi  siparis_gunu haftanin_gunu  hafta_numarasi  \
# 0            1            13      Saturday               2
# 1            8            10      Saturday              32
# 2            8            19        Monday              34
# 3            8             9      Saturday              32
# 4            7            30       Tuesday              31
#
#             ay_donemi hafta_tipi  iki_haftalik_donem
# 0    Ayın ilk yarısı   haftasonu                   1
# 1    Ayın ilk yarısı   haftasonu                  16
# 2  Ayın ikinci yarısı   haftaiçi                  17
# 3    Ayın ilk yarısı   haftasonu                  16
# 4  Ayın ikinci yarısı   haftaiçi                  16

# %%
iki_haftalik_analiz=(
    df.groupby("iki_haftalik_donem")
    .agg(
        ortalama_siparis_tutari=("toplam_tutar","mean")
    ).round(2)
    .reset_index()
    .sort_values("iki_haftalik_donem")
    )
iki_haftalik_analiz
# Out:
#     iki_haftalik_donem  ortalama_siparis_tutari
# 0                    1                   744.65
# 1                    2                   667.21
# 2                    3                   895.91
# 3                    4                   822.83
# 4                    5                   679.51
# 5                    6                   751.62
# 6                    7                   773.34
# 7                    8                   603.19
# 8                    9                   606.74
# 9                   10                   876.16
# 10                  11                   922.32
# 11                  12                   911.21
# 12                  13                   916.68
# 13                  14                   917.74
# 14                  15                   834.07
# 15                  16                   719.16
# 16                  17                   716.24
# 17                  18                   779.29
# 18                  19                   947.00
# 19                  20                   779.99
# 20                  21                   691.27
# 21                  22                   744.24
# 22                  23                   621.77
# 23                  24                   810.49
# 24                  25                   865.33
# 25                  26                   646.97

# %%
plt.figure(figsize=(10,4))
plt.plot(iki_haftalik_analiz["iki_haftalik_donem"],iki_haftalik_analiz["ortalama_siparis_tutari"],marker="o")
plt.title("iki haftalık dönemlere göre ortalama sipariş tutarı")
plt.xlabel("iki haftalık dönem")
plt.xticks(iki_haftalik_analiz["iki_haftalik_donem"])
plt.ylabel("ortalama siparis tutari")
plt.show()

# %% [markdown]
# ## Değişkenler Arası İlişkiler
# Amaç:
# 1. Sayısal değişkenler arasındaki ilişkileri korelasyon analizi ile incelemek
# 2. Heatmap ile görselleştirme yapmak
# Adımlar:
# 1. Veri setini yüklemek
# 2. sayısal sütunları belirle
# 3. Korelasyon matrisi oluştur
# 4. Korelasyon matrisini heatmap ile görselleştir

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("e_ticaret_veri_seti_aykiri_degerler_duzenlendi.csv")
df.head()
# Out:
#   siparis_id musteri_id       siparis_tarihi      sehir              bolge  \
# 0  SIP101125    MUS1391  2024-01-13 17:06:00   İstanbul            Marmara
# 1  SIP100263    MUS1008  2024-08-10 15:13:00    Antalya            Akdeniz
# 2  SIP100707    MUS1291  2024-08-19 08:24:00  Gaziantep  Güneydoğu Anadolu
# 3  SIP100687    MUS1147  2025-08-09 08:42:00      Konya         İç Anadolu
# 4  SIP100254    MUS1447  2024-07-30 09:06:00      Konya         İç Anadolu
#
#      kategori            urun_adi  adet  birim_fiyat  indirim_orani  ...  \
# 0    Kozmetik        Nemlendirici     1       414.51           0.05  ...
# 1       Kitap        Girişimcilik     5       194.78           0.00  ...
# 2  Elektronik           Powerbank     3       841.80           0.05  ...
# 3    Kozmetik        Nemlendirici     2       417.02           0.00  ...
# 4  Elektronik  Bluetooth Hoparlör     1      1327.75           0.05  ...
#
#    musteri_tipi teslimat_gunu musteri_puani  iade_durumu  kar_marji_orani  \
# 0          Yeni           3.0           5.0        Hayır            0.220
# 1          Yeni           3.0           5.0        Hayır            0.250
# 2        Mevcut           4.0           5.0        Hayır            0.280
# 3        Mevcut           4.0           5.0        Hayır            0.220
# 4        Mevcut           4.0           5.0        Hayır            0.283
#
#   toplam_tutar  siparis_yili  siparis_ayi  siparis_gunu  haftanin_gunu
# 0       443.68          2024            1            13       Saturday
# 1      1023.80          2024            8            10       Saturday
# 2      2439.03          2024            8            19         Monday
# 3       893.94          2025            8             9       Saturday
# 4      1291.26          2024            7            30        Tuesday
#
# [5 rows x 22 columns]

# %%
#sayısal süütunları belirle
sayisal_sutunlar=df.select_dtypes(include=["float64","int64"]).columns.tolist()

# %%
#korelasyon matrisini oluşturma
korelasyon_matrisi=df[sayisal_sutunlar].corr()
korelasyon_matrisi
# Out:
#                      adet  birim_fiyat  indirim_orani  kargo_ucreti  \
# adet             1.000000    -0.172071       0.016591      0.033094
# birim_fiyat     -0.172071     1.000000      -0.002181      0.019820
# indirim_orani    0.016591    -0.002181       1.000000     -0.005396
# kargo_ucreti     0.033094     0.019820      -0.005396      1.000000
# teslimat_gunu    0.001184    -0.005320       0.059778     -0.007760
# musteri_puani   -0.008471     0.009712       0.008851      0.025023
# kar_marji_orani -0.000069    -0.008091      -0.009713     -0.000559
# toplam_tutar     0.431589     0.715181      -0.029132      0.033540
# siparis_yili     0.029008    -0.028609       0.027660      0.078653
# siparis_ayi      0.072723    -0.029080       0.026244     -0.013895
# siparis_gunu    -0.003461    -0.033501       0.016658      0.001687
#
#                  teslimat_gunu  musteri_puani  kar_marji_orani  toplam_tutar  \
# adet                  0.001184      -0.008471        -0.000069      0.431589
# birim_fiyat          -0.005320       0.009712        -0.008091      0.715181
# indirim_orani         0.059778       0.008851        -0.009713     -0.029132
# kargo_ucreti         -0.007760       0.025023        -0.000559      0.033540
# teslimat_gunu         1.000000       0.015807         0.007860      0.003866
# musteri_puani         0.015807       1.000000        -0.014840      0.011660
# kar_marji_orani       0.007860      -0.014840         1.000000     -0.007492
# toplam_tutar          0.003866       0.011660        -0.007492      1.000000
# siparis_yili          0.038177      -0.044280        -0.030443     -0.006989
# siparis_ayi           0.002053      -0.055970         0.042821      0.018804
# siparis_gunu         -0.023197      -0.032129        -0.031069     -0.032507
#
#                  siparis_yili  siparis_ayi  siparis_gunu
# adet                 0.029008     0.072723     -0.003461
# birim_fiyat         -0.028609    -0.029080     -0.033501
# indirim_orani        0.027660     0.026244      0.016658
# kargo_ucreti         0.078653    -0.013895      0.001687
# teslimat_gunu        0.038177     0.002053     -0.023197
# musteri_puani       -0.044280    -0.055970     -0.032129
# kar_marji_orani     -0.030443     0.042821     -0.031069
# toplam_tutar        -0.006989     0.018804     -0.032507
# siparis_yili         1.000000     0.047170     -0.032772
# siparis_ayi          0.047170     1.000000     -0.029934
# siparis_gunu        -0.032772    -0.029934      1.000000

# %%
#korelasyon matrisini heatmap ile görselleştirme
sns.heatmap(korelasyon_matrisi,annot=True,fmt=".1f", cmap="coolwarm" , linewidth=0.5)
plt.title("korelasyon analizi")
plt.show()

# %% [markdown]
# ## Veri Hikayeleştirme ve İş Yorumu
# Amaç:
# 1. Gerçek hayata benzeyen iş sorularını veri ile cevaplamak
# 2. Analiz sonuçlarını tablo, grafik ve kısa iş yorumları ile sunmak
# Adımlar:
# 1. Hangi kategori hem yüksek gelir üretiyor hem de müşteri memnuniyeti açısından güçlü görünüyor?
# 2. Hangi ödeme türleri daha yüksek ortalama sipariş tutarı üretiyor ve müşteri puanı açısından performans gösteriyor?
# 3. Hangi şehir-kategori kombinasyonları en güçlü fırsatı sunuyor

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#veri setini yükleme
df=pd.read_csv("e_ticaret_veri_seti_aykiri_degerler_duzenlendi.csv")
df.head()
# Out:
#   siparis_id musteri_id       siparis_tarihi      sehir              bolge  \
# 0  SIP101125    MUS1391  2024-01-13 17:06:00   İstanbul            Marmara
# 1  SIP100263    MUS1008  2024-08-10 15:13:00    Antalya            Akdeniz
# 2  SIP100707    MUS1291  2024-08-19 08:24:00  Gaziantep  Güneydoğu Anadolu
# 3  SIP100687    MUS1147  2025-08-09 08:42:00      Konya         İç Anadolu
# 4  SIP100254    MUS1447  2024-07-30 09:06:00      Konya         İç Anadolu
#
#      kategori            urun_adi  adet  birim_fiyat  indirim_orani  ...  \
# 0    Kozmetik        Nemlendirici     1       414.51           0.05  ...
# 1       Kitap        Girişimcilik     5       194.78           0.00  ...
# 2  Elektronik           Powerbank     3       841.80           0.05  ...
# 3    Kozmetik        Nemlendirici     2       417.02           0.00  ...
# 4  Elektronik  Bluetooth Hoparlör     1      1327.75           0.05  ...
#
#    musteri_tipi teslimat_gunu musteri_puani  iade_durumu  kar_marji_orani  \
# 0          Yeni           3.0           5.0        Hayır            0.220
# 1          Yeni           3.0           5.0        Hayır            0.250
# 2        Mevcut           4.0           5.0        Hayır            0.280
# 3        Mevcut           4.0           5.0        Hayır            0.220
# 4        Mevcut           4.0           5.0        Hayır            0.283
#
#   toplam_tutar  siparis_yili  siparis_ayi  siparis_gunu  haftanin_gunu
# 0       443.68          2024            1            13       Saturday
# 1      1023.80          2024            8            10       Saturday
# 2      2439.03          2024            8            19         Monday
# 3       893.94          2025            8             9       Saturday
# 4      1291.26          2024            7            30        Tuesday
#
# [5 rows x 22 columns]

# %%
#hangi kategori hem yüksek gelir hem de müşteri memnuniyetini yüksek sağlıyor
kategori_raporu=(
    df.groupby("kategori")
    .agg(
        toplam_gelir=("toplam_tutar","sum"),
        ortalama_musteri_puani=("musteri_puani","mean")
    )
    .round(2)
)

# %%
kategori_raporu=kategori_raporu.sort_values( by = ["toplam_gelir"], ascending=[False])
kategori_raporu
# Out:
#             toplam_gelir  ortalama_musteri_puani
# kategori
# Elektronik     212930.29                    4.24
# Spor           189481.91                    4.26
# Kozmetik       147522.90                    4.42
# Ev Yaşam       142335.55                    4.26
# Kitap          114075.59                    4.25
# Ofis            47051.88                    4.24

# %%
#kategoriye göre toplam gelir grafiği
plt.figure(figsize=(8,4))
sns.barplot(data=kategori_raporu, x = "kategori" , y = "toplam_gelir")
plt.title("kategoriye göre toplam gelir")
plt.xlabel("kategori")
plt.ylabel("toplam gelir")
plt.show()

# %%
#kategoriye göre ortalama müşteri puanı grafiği
plt.figure(figsize=(8,4))
sns.barplot(data=kategori_raporu, x = "kategori" , y = "ortalama_musteri_puani")
plt.title("kategoriye göre ortalama müşteri puanı")
plt.xlabel("kategori")
plt.ylabel("müşteri puanı")
plt.show()

# %%
#hangi ödeme türleri daha yüksek ortalama sipariş tutarı üretiyor ve müşteri puanı açısından nasıl performans gösteriyor
odeme_turu_raporu=(
    df.groupby("odeme_turu")
    .agg(
        ortalama_siparis_tutari=("toplam_tutar","mean"),
        ortalama_musteri_puani=("musteri_puani","mean")
    )
    .round(2)
    .sort_values("ortalama_siparis_tutari",ascending=False)
    )
odeme_turu_raporu
# Out:
#                 ortalama_siparis_tutari  ortalama_musteri_puani
# odeme_turu
# Dijital Cüzdan                   849.09                    4.27
# Banka Kartı                      846.22                    4.24
# Havale/EFT                       836.89                    4.15
# Kredi Kartı                      753.80                    4.31
# Kapıda Ödeme                     609.03                    4.38

# %%
#ödeme türüne göre ortalama ortalama sipariş tutarı grafiği
plt.figure(figsize=(8,4))
sns.barplot(data=odeme_turu_raporu, x = "odeme_turu" , y = "ortalama_siparis_tutari")
plt.title("ödeme türüne göre ortalama ortalama sipariş tutarı")
plt.xlabel("odeme_turu")
plt.ylabel("ortalama sipariş tutarı")
plt.show()

# %%
#ödeme türüne göre ortalama ortalama müşteri puanı grafiği
plt.figure(figsize=(8,4))
sns.barplot(data=odeme_turu_raporu, x = "odeme_turu" , y = "ortalama_musteri_puani")
plt.title("ödeme türüne göre ortalama ortalama müşteri puanı")
plt.xlabel("odeme_turu")
plt.ylabel("ortalama müşteri puanı")
plt.show()

# %%
#hangi şehir-kategori kombinasyonları en güçlü fırsatı sunuyor
sehir_kategori_raporu=(
    df.groupby(["sehir","kategori"])
    .agg(
        toplam_gelir=("toplam_tutar","sum")
    )
    .round(2)
    .sort_values(["toplam_gelir"],ascending=False)
)
sehir_kategori_raporu
# Out:
#                       toplam_gelir
# sehir     kategori
# İstanbul  Elektronik      66731.92
#           Spor            53391.34
#           Ev Yaşam        34130.59
#           Kozmetik        33167.28
#           Kitap           27106.12
# ...                            ...
# Eskişehir Ofis             1727.90
# Kayseri   Elektronik       1715.61
# Kocaeli   Ofis             1026.94
# Kayseri   Ofis              868.53
# Kocaeli   Elektronik        779.13
#
# [84 rows x 1 columns]

# %%
#en güçlü 10 şehir-kategori kombinasyonunu görselleştir
en_guclu_10_kombinasyon=sehir_kategori_raporu.head(10).reset_index()
plt.figure(figsize=(8,4))
sns.barplot(
    data=en_guclu_10_kombinasyon,
    x="sehir",
    y="toplam_gelir",
    hue="kategori"
)
plt.title("en güçlü 10 şehir-kategori kombinasyonu")
plt.xlabel("şehir")
plt.ylabel("toplam gelir")
# Out:
# Text(0, 0.5, 'toplam gelir')
